# %% [markdown]
# # Project: Analysis of Tweet Data of WeRateDogs Twitter Account
# By: __[Edun Joshua. O](https://www.linkedin.com/in/joshua-edun)__ <br>
# For Udacity
# ## Table of Contents
# <ul>
#     <li><a href="#intro">Introduction</a></li>
#     <li><a href="#sources">Data Sources</a></li>
#     <li><a href="#gathering">Data Gathering</a></li>
#     <li><a href="#assessing">Data Assessing</a></li>
#         <li><a href="#assessingsum">Assessing Summary</a></li>
#     <li><a href="#cleaning">Data Cleaning</a></li>
#     <li><a href="#storing">Data Storing</a></li>
#     <li><a href="#analysis">Data Analysis and Visualizations</a></li>
#     <li><a href="#conclusion">Conclusion & Limitations</a></li>
#     <li><a href="#report">Report</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# # `Introduction`
#
# The dataset comes from the tweet archive of Twitter user `@dog_rates`, also known as WeRateDogs.<br>
#
# WeRateDogs is a Twitter account that rates people's dogs with a humourous comment about the dog. These ratings almost always have a denominator of 10 though the numerators can be adsurdly large. Why? Because "they're good dogs Brent." WeRateDogs has over 4 million followers and has received international media coverage.
#
# I got access to their tweet archive via Udacity. This archive contains basic tweet data (tweet ID, timestamp, text, etc.) for all 5000+ of their tweets as they stood on August 1, 2017.
#
# The Data Gathering process is supposed to comprise 3 methods of gathering data:
# >**The WeRateDogs Twitter archive**<br>
# To be downloaded manually
#
# >**The tweet image predictions**<br>
# image_predictions.tsv... To be downloaded programmatically
#
# >**Additional data from the Twitter API**<br>
# Each tweet's retweet count and favorite ("like") is to be queried from Twitter's API into a file, tweet_json.txt.<br>
# However, due to my Twitter Developer account not being verified in time, I proceeded to download this file manually as Udacity foresaw scenarios like this.

# %%
# importing necessary libraries
import numpy as np, pandas as pd
import matplotlib.pyplot as plt, seaborn as sns
import json
import re
import requests

# %% [markdown]
# <a id='gathering'></a>
# # `Gather`

# %%
 # The WeRateDogs Twitter archive
df_tweets = pd.read_csv('twitter-archive-enhanced.csv')
df_tweets.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %%
# downloading programmatically
url = "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"

#get response
response = requests.get(url)


with open("image_predictions.tsv", mode = "wb") as file:
    file.write(response.content)

# %%
# reading in
df_neural = pd.read_csv("image_predictions.tsv", sep='\t')

df_neural.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %%
# API
# My developer account was not authenticated in time so I resorted to directly importing the JSON .txt file Udacity provided
json_tweets = []

#read the created file
with open('tweet_json.txt', 'r') as f:
    for line in f:
       # try: 
            tweet = json.loads(line)
            #append a dictionary to the created list            
            json_tweets.append({
                'tweet_id': tweet['id'],
                'retweet_count': tweet['retweet_count'],
                'favorite_count': tweet['favorite_count'],
                       
            })

# %%
df_json = pd.DataFrame(json_tweets, columns = ['tweet_id', 'retweet_count', 'favorite_count'])
df_json.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           8287           37931
# 1  892177421306343426           6119           32575
# 2  891815181378084864           4054           24530
# 3  891689557279858688           8424           41274
# 4  891327558926688256           9128           39464

# %% [markdown]
# --------

# %% [markdown]
# <a id='assessing'></a>
# # `Assess`
# ### checking for data quality and structural issues in all three datasets
#  - Visually
#  - Programmatically
#
# I will begin with df_tweets

# %% [markdown]
# **`1(a)`**<br>
# ### **Visual Assessment of `df_tweets`**

# %%
# Visual assessment
df_tweets.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %%
# Visual assessment
df_tweets.tail()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator  name doggo floofer pupper puppo
# 2351                  10  None  None    None   None  None
# 2352                  10     a  None    None   None  None
# 2353                  10     a  None    None   None  None
# 2354                  10     a  None    None   None  None
# 2355                  10  None  None    None   None  None

# %%
# Visual assessment
df_tweets.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1587  686749460672679938                    NaN                  NaN
# 1360  703268521220972544                    NaN                  NaN
# 2191  668955713004314625                    NaN                  NaN
# 1849  675781562965868544                    NaN                  NaN
# 806   772102971039580160                    NaN                  NaN
#
#                       timestamp  \
# 1587  2016-01-12 03:20:05 +0000
# 1360  2016-02-26 17:20:56 +0000
# 2191  2015-11-24 00:54:05 +0000
# 1849  2015-12-12 20:57:34 +0000
# 806   2016-09-03 16:04:27 +0000
#
#                                                  source  \
# 1587  <a href="http://twitter.com/download/iphone" r...
# 1360  <a href="http://twitter.com/download/iphone" r...
# 2191  <a href="http://twitter.com/download/iphone" r...
# 1849  <a href="http://twitter.com/download/iphone" r...
# 806   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1587  Strange pup here. Easily manipulated. Rather i...                  NaN
# 1360  Happy Friday here's a sleepy pupper 12/10 http...                  NaN
# 2191  This is a Slovakian Helter Skelter Feta named ...                  NaN
# 1849  Say hello to Buddah. He was Waldo for Hallowee...                  NaN
# 806   This is Penny. She's an OU cheerleader. About ...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1587                       NaN                        NaN
# 1360                       NaN                        NaN
# 2191                       NaN                        NaN
# 1849                       NaN                        NaN
# 806                        NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1587  https://twitter.com/dog_rates/status/686749460...                 8
# 1360  https://twitter.com/dog_rates/status/703268521...                12
# 2191  https://twitter.com/dog_rates/status/668955713...                10
# 1849  https://twitter.com/dog_rates/status/675781562...                11
# 806   https://twitter.com/dog_rates/status/772102971...                11
#
#       rating_denominator    name doggo floofer  pupper puppo
# 1587                  10    None  None    None    None  None
# 1360                  10    None  None    None  pupper  None
# 2191                  10       a  None    None    None  None
# 1849                  10  Buddah  None    None    None  None
# 806                   10   Penny  None    None    None  None

# %% [markdown]
# -------
# **`1(b)`**<br>
# ### **Programmatic Assessment of `df_tweets`**

# %%
df_tweets.shape
# Out:
# (2356, 17)

# %%
df_tweets.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %%
df_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
# calculating the number of nulls per column
df_tweets.isna().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %%
# calculating the percentage of nulls
nans = df_tweets.isna().mean() * 100
nans.sort_values(ascending=False)
# Out:
# in_reply_to_user_id           96.689304
# in_reply_to_status_id         96.689304
# retweeted_status_timestamp    92.317487
# retweeted_status_id           92.317487
# retweeted_status_user_id      92.317487
# expanded_urls                  2.504244
# rating_denominator             0.000000
# pupper                         0.000000
# floofer                        0.000000
# doggo                          0.000000
# name                           0.000000
# tweet_id                       0.000000
# rating_numerator               0.000000
# text                           0.000000
# source                         0.000000
# timestamp                      0.000000
# puppo                          0.000000
# dtype: float64

# %%
# summary statistics
df_tweets.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# 25%           7.186315e+17              4.196984e+09         10.000000
# 50%           7.804657e+17              4.196984e+09         11.000000
# 75%           8.203146e+17              4.196984e+09         12.000000
# max           8.874740e+17              7.874618e+17       1776.000000
#
#        rating_denominator
# count         2356.000000
# mean            10.455433
# std              6.745237
# min              0.000000
# 25%             10.000000
# 50%             10.000000
# 75%             10.000000
# max            170.000000

# %%
# summary stats for object dtype columns
df_tweets.describe(include='object')
# Out:
#                         timestamp  \
# count                        2356
# unique                       2356
# top     2017-08-01 16:23:56 +0000
# freq                            1
#
#                                                    source  \
# count                                                2356
# unique                                                  4
# top     <a href="http://twitter.com/download/iphone" r...
# freq                                                 2221
#
#                                                      text  \
# count                                                2356
# unique                                               2356
# top     This is Phineas. He's a mystical boy. Only eve...
# freq                                                    1
#
#        retweeted_status_timestamp  \
# count                         181
# unique                        181
# top     2017-07-19 00:47:34 +0000
# freq                            1
#
#                                             expanded_urls  name doggo floofer  \
# count                                                2297  2356  2356    2356
# unique                                               2218   957     2       2
# top     https://twitter.com/dog_rates/status/667152164...  None  None    None
# freq                                                    2   745  2259    2346
#
#        pupper puppo
# count    2356  2356
# unique      2     2
# top      None  None
# freq     2099  2326

# %%
# checking for duplicates
df_tweets[df_tweets.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
# visualizing missing data
fig, ax = plt.subplots(figsize = (20,8))
ax = sns.heatmap(df_tweets.isnull(), vmin=0, vmax = 1)
plt.show()

# %% [markdown]
# ### **Further Assessment** (deep dive into individual columns)

# %% [markdown]
# ### tweet_id

# %%
# checking the values for extremes
df_tweets['tweet_id'].sort_values()
# Out:
# 2355    666020888022790149
# 2354    666029285002620928
# 2353    666033412701032449
# 2352    666044226329800704
# 2351    666049248165822465
#                ...
# 4       891327558926688256
# 3       891689557279858688
# 2       891815181378084864
# 1       892177421306343426
# 0       892420643555336193
# Name: tweet_id, Length: 2356, dtype: int64

# %%
# sampling the data
df_tweets['tweet_id'].sample(5)
# Out:
# 43      884162670584377345
# 2152    669680153564442624
# 1948    673697980713705472
# 1551    689143371370250240
# 1602    685973236358713344
# Name: tweet_id, dtype: int64

# %% [markdown]
# ### timestamp

# %%
# sampling the columns
df_tweets['timestamp'].sample(5)
# Out:
# 2172    2015-11-25 01:30:16 +0000
# 860     2016-08-10 00:16:21 +0000
# 1124    2016-05-11 01:44:07 +0000
# 2301    2015-11-18 18:17:59 +0000
# 200     2017-04-17 16:34:26 +0000
# Name: timestamp, dtype: object

# %%
# sorting values
df_tweets['timestamp'].sort_values()
# Out:
# 2355    2015-11-15 22:32:08 +0000
# 2354    2015-11-15 23:05:30 +0000
# 2353    2015-11-15 23:21:54 +0000
# 2352    2015-11-16 00:04:52 +0000
# 2351    2015-11-16 00:24:50 +0000
#                   ...
# 4       2017-07-29 16:00:24 +0000
# 3       2017-07-30 15:58:51 +0000
# 2       2017-07-31 00:18:03 +0000
# 1       2017-08-01 00:17:27 +0000
# 0       2017-08-01 16:23:56 +0000
# Name: timestamp, Length: 2356, dtype: object

# %% [markdown]
# ### source

# %%
# sampling the data
df_tweets['source'].sample(10)
# Out:
# 99      <a href="http://twitter.com/download/iphone" r...
# 25      <a href="http://twitter.com/download/iphone" r...
# 737     <a href="http://twitter.com/download/iphone" r...
# 2263    <a href="http://twitter.com" rel="nofollow">Tw...
# 748     <a href="http://twitter.com/download/iphone" r...
# 1728    <a href="http://vine.co" rel="nofollow">Vine -...
# 1353    <a href="http://twitter.com/download/iphone" r...
# 974     <a href="https://about.twitter.com/products/tw...
# 378     <a href="http://twitter.com/download/iphone" r...
# 294     <a href="http://twitter.com/download/iphone" r...
# Name: source, dtype: object

# %% [markdown]
# ### expanded_url

# %% [markdown]
# *I suspect this archive contains retweets*<br>
# *I'll check for that now...*

# %%
mask = df_tweets.duplicated(subset='expanded_urls', keep='last')
df_tweets[['expanded_urls', 'text']][mask].dropna()
# Out:
#                                           expanded_urls  \
# 68    https://twitter.com/dog_rates/status/878057613...
# 73    https://www.gofundme.com/3yd6y1c,https://twitt...
# 74    https://twitter.com/dog_rates/status/669000397...
# 91    https://twitter.com/dog_rates/status/866334964...
# 97    https://www.gofundme.com/help-my-baby-sierra-g...
# ...                                                 ...
# 860   https://twitter.com/dog_rates/status/673295268...
# 937   https://twitter.com/dog_rates/status/681523177...
# 1012  https://twitter.com/dog_rates/status/704761120...
# 1023  https://twitter.com/dog_rates/status/667866724...
# 1043  https://twitter.com/dog_rates/status/667138269...
#
#                                                    text
# 68    RT @dog_rates: This is Emmy. She was adopted t...
# 73    RT @dog_rates: Meet Shadow. In an attempt to r...
# 74    RT @dog_rates: Meet Terrance. He's being yelle...
# 91    RT @dog_rates: This is Coco. At first I though...
# 97    RT @dog_rates: This is Sierra. She's one preci...
# ...                                                 ...
# 860   RT @dog_rates: Meet Eve. She's a raging alcoho...
# 937   RT @dog_rates: This is Carly. She's actually 2...
# 1012  RT @dog_rates: This pupper killed this great w...
# 1023  RT @dog_rates: This is Shaggy. He knows exactl...
# 1043  RT @dog_rates: Extremely intelligent dog here....
#
# [79 rows x 2 columns]

# %%
# checking for duplicate images and tweet ids
mask = df_tweets[['tweet_id','expanded_urls']].duplicated(keep=False)
df_tweets[mask]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# *There are retweets in this archive and they are all prefixed by `RT`*

# %% [markdown]
# ### text

# %%
# checking for duplicates
mask = df_tweets.duplicated(subset='text', keep='last')
df_tweets[mask]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# ### rating_numerator

# %%
# checking value counts
df_tweets['rating_numerator'].value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 2         9
# 1         9
# 75        2
# 15        2
# 420       2
# 0         2
# 80        1
# 144       1
# 17        1
# 26        1
# 20        1
# 121       1
# 143       1
# 44        1
# 60        1
# 45        1
# 50        1
# 99        1
# 204       1
# 1776      1
# 165       1
# 666       1
# 27        1
# 182       1
# 24        1
# 960       1
# 84        1
# 88        1
# Name: rating_numerator, dtype: int64

# %% [markdown]
# *I will perform checks on the ratings with the fewest counts to check for parsing errors*

# %%
# checking value counts
df_tweets['rating_numerator'].value_counts().tail(26)
# Out:
# 75      2
# 15      2
# 420     2
# 0       2
# 80      1
# 144     1
# 17      1
# 26      1
# 20      1
# 121     1
# 143     1
# 44      1
# 60      1
# 45      1
# 50      1
# 99      1
# 204     1
# 1776    1
# 165     1
# 666     1
# 27      1
# 182     1
# 24      1
# 960     1
# 84      1
# 88      1
# Name: rating_numerator, dtype: int64

# %%
# getting the numerators with the lowest count and putting into a list
num = df_tweets['rating_numerator'].value_counts().tail(26).index.to_list()
num
# Out:
# [75,
#  15,
#  420,
#  0,
#  80,
#  144,
#  17,
#  26,
#  20,
#  121,
#  143,
#  44,
#  60,
#  45,
#  50,
#  99,
#  204,
#  1776,
#  165,
#  666,
#  27,
#  182,
#  24,
#  960,
#  84,
#  88]

# %%
# writing a loop to print the text containing the ratings for each numerator in num defined above
for n in num:
    print(f"numerator: {n}")
    print(f"{df_tweets['text'][df_tweets['rating_numerator'] == n]} \n")
# Out:
# numerator: 75
# 340    RT @dog_rates: This is Logan, the Chow who liv...
# 695    This is Logan, the Chow who lived. He solemnly...
# Name: text, dtype: object
#
# numerator: 15
# 285    RT @KibaDva: I collected all the good dogs!! 1...
# 291    @bragg6of8 @Andy_Pace_ we are still looking fo...
# Name: text, dtype: object
#
# numerator: 420
# 188     @dhmontgomery We also gave snoop dogg a 420/10...
# 2074    After so many requests... here you go.\n\nGood...
# Name: text, dtype: object
#
# numerator: 0
# 315     When you're so blinded by your systematic plag...
# 1016    PUPDATE: can't see any. Even if I could, I cou...
# Name: text, dtype: object
#
# numerator: 80
# 1254    Here's a brigade of puppers. All look very pre...
# Name: text, dtype: object
#
# numerator: 144
# 1779    IT'S PUPPERGEDDON. Total of 144/120 ...I think...
# Name: text, dtype: object
#
# numerator: 17
# 55    @roushfenway These are good dogs but 17/10 is ...
# Name: text, dtype: object
#
# numerator: 26
# 1712    Here we have uncovered an entire battalion of ...
# Name: text, dtype: object
#
# numerator: 20
# 1663    I'm aware that I could've said 20/16, but here...
# Name: text, dtype: object
#
# numerator: 121
# 1635    Someone help the girl is being mugged. Several...
# Name: text, dtype: object
#
# numerator: 143
# 1634    Two sneaky puppers were not initially seen, mo...
# Name: text, dtype: object
#
# numerator: 44
# 1433    Happy Wednesday here's a bucket of pups. 44/40...
# Name: text, dtype: object
#
# numerator: 60
# 1351    Here is a whole flock of puppers.  60/50 I'll ...
# Name: text, dtype: object
#
# numerator: 45
# 1274    From left to right:\nCletus, Jerome, Alejandro...
# Name: text, dtype: object
#
# numerator: 50
# 1202    This is Bluebert. He just saw that both #Final...
# Name: text, dtype: object
#
# numerator: 99
# 1228    Happy Saturday here's 9 puppers on a bench. 99...
# Name: text, dtype: object
#
# numerator: 204
# 1120    Say hello to this unbelievably well behaved sq...
# Name: text, dtype: object
#
# numerator: 1776
# 979    This is Atticus. He's quite simply America af....
# Name: text, dtype: object
#
# numerator: 165
# 902    Why does this never happen at my front door......
# Name: text, dtype: object
#
# numerator: 666
# 189    @s8n You tried very hard to portray this good ...
# Name: text, dtype: object
#
# numerator: 27
# 763    This is Sophie. She's a Jubilant Bush Pupper. ...
# Name: text, dtype: object
#
# numerator: 182
# 290    @markhoppus 182/10
# Name: text, dtype: object
#
# numerator: 24
# 516    Meet Sam. She smiles 24/7 &amp; secretly aspir...
# Name: text, dtype: object
#
# numerator: 960
# 313    @jonnysun @Lin_Manuel ok jomny I know you're e...
# Name: text, dtype: object
#
# numerator: 84
# 433    The floofs have been released I repeat the flo...
# Name: text, dtype: object
#
# numerator: 88
# 1843    Here we have an entire platoon of puppers. Tot...
# Name: text, dtype: object

# %% [markdown]
# *Ratings of numerator one seem low for such a cheery tweet archive*.<br>
# *Checking for these ratings...*

# %%
df_tweets['text'][df_tweets['rating_numerator'] == 1]
# Out:
# 605     RT @dog_rates: Not familiar with this breed. N...
# 1446    After reading the comments I may have overesti...
# 1869    What kind of person sends in a picture without...
# 1940    The millennials have spoken and we've decided ...
# 2038    After 22 minutes of careful deliberation this ...
# 2091    Flamboyant pup here. Probably poisonous. Won't...
# 2261    Never seen dog like this. Breathes heavy. Tilt...
# 2335    This is an Albanian 3 1/2 legged  Episcopalian...
# 2338    Not familiar with this breed. No tail (weird)....
# Name: text, dtype: object

# %% [markdown]
# *checking for ratings of numerator two too...*

# %%
df_tweets['text'][df_tweets['rating_numerator'] == 2]
# Out:
# 1761    Exotic pup here. Tail long af. Throat looks sw...
# 1764    This is Crystal. She's a shitty fireman. No se...
# 1920    This is Henry. He's a shit dog. Short pointy e...
# 2079    Scary dog here. Too many legs. Extra tail. Not...
# 2237    This lil pup is Oliver. Hops around. Has wings...
# 2246    This is Tedrick. He lives on the edge. Needs s...
# 2310    Unfamiliar with this breed. Ears pointy af. Wo...
# 2326    This is quite the dog. Gets really excited whe...
# 2349    This is an odd dog. Hard on the outside but lo...
# Name: text, dtype: object

# %% [markdown]
# ### Summary of parsing errors assessment
# > *row 340 : numerator is actually 9.75. Parsed as 75*<br>
# > *row 695 : numerator is actually 9.75. Parsed as 75 (Duplicate of row 340)*<br>
# > *row 55 : numerator is actually 13. Parsed as 17*<br>
# > *row 1712 : numerator is actually 11.26. Parsed as 26*<br>
# > *row 1202 : numerator is actually 11. Parsed as 50*<br>
# > *row 763 : numerator is actually 11.27. Parsed as 27*<br>
# > *row  313 :  contains a retweet of a non-existent post. should be removed*<br>
# > *row 2335 : numerator is actually 9. Parsed as 1*

# %% [markdown]
# ### rating_denominator

# %%
# checking value counts
df_tweets['rating_denominator'].value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 20        2
# 80        2
# 70        1
# 7         1
# 15        1
# 150       1
# 170       1
# 0         1
# 90        1
# 40        1
# 130       1
# 110       1
# 16        1
# 120       1
# 2         1
# Name: rating_denominator, dtype: int64

# %%
# checking value counts
df_tweets['rating_denominator'].value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 20        2
# 80        2
# 70        1
# 7         1
# 15        1
# 150       1
# 170       1
# 0         1
# 90        1
# 40        1
# 130       1
# 110       1
# 16        1
# 120       1
# 2         1
# Name: rating_denominator, dtype: int64

# %%
# getting the denominators with the lowest count, excluding 10 and putting into a list
den = df_tweets['rating_denominator'].value_counts().tail(17).index.to_list()
den
# Out:
# [11, 50, 20, 80, 70, 7, 15, 150, 170, 0, 90, 40, 130, 110, 16, 120, 2]

# %%
# writing a loop to print the text containing the ratings for each numerator in num defined above
for d in den:
    print(f"denominator: {d}")
    print(f"{df_tweets['text'][df_tweets['rating_denominator'] == d]} \n")
# Out:
# denominator: 11
# 784     RT @dog_rates: After so many requests, this is...
# 1068    After so many requests, this is Bretagne. She ...
# 1662    This is Darrel. He just robbed a 7/11 and is i...
# Name: text, dtype: object
#
# denominator: 50
# 1202    This is Bluebert. He just saw that both #Final...
# 1274    From left to right:\nCletus, Jerome, Alejandro...
# 1351    Here is a whole flock of puppers.  60/50 I'll ...
# Name: text, dtype: object
#
# denominator: 20
# 1165    Happy 4/20 from the squad! 13/10 for all https...
# 1598    Yes I do realize a rating of 4/20 would've bee...
# Name: text, dtype: object
#
# denominator: 80
# 1254    Here's a brigade of puppers. All look very pre...
# 1843    Here we have an entire platoon of puppers. Tot...
# Name: text, dtype: object
#
# denominator: 70
# 433    The floofs have been released I repeat the flo...
# Name: text, dtype: object
#
# denominator: 7
# 516    Meet Sam. She smiles 24/7 &amp; secretly aspir...
# Name: text, dtype: object
#
# denominator: 15
# 342    @docmisterio account started on 11/15/15
# Name: text, dtype: object
#
# denominator: 150
# 902    Why does this never happen at my front door......
# Name: text, dtype: object
#
# denominator: 170
# 1120    Say hello to this unbelievably well behaved sq...
# Name: text, dtype: object
#
# denominator: 0
# 313    @jonnysun @Lin_Manuel ok jomny I know you're e...
# Name: text, dtype: object
#
# denominator: 90
# 1228    Happy Saturday here's 9 puppers on a bench. 99...
# Name: text, dtype: object
#
# denominator: 40
# 1433    Happy Wednesday here's a bucket of pups. 44/40...
# Name: text, dtype: object
#
# denominator: 130
# 1634    Two sneaky puppers were not initially seen, mo...
# Name: text, dtype: object
#
# denominator: 110
# 1635    Someone help the girl is being mugged. Several...
# Name: text, dtype: object
#
# denominator: 16
# 1663    I'm aware that I could've said 20/16, but here...
# Name: text, dtype: object
#
# denominator: 120
# 1779    IT'S PUPPERGEDDON. Total of 144/120 ...I think...
# Name: text, dtype: object
#
# denominator: 2
# 2335    This is an Albanian 3 1/2 legged  Episcopalian...
# Name: text, dtype: object

# %% [markdown]
# ### Summary of parsing errors assessment
# > *row 784 : denominator is actually 10. Parsed as 11*<br>
# > *row 1068 : seems to be a duplicate of row 784*<br>
# > *row 1662 : denominator is actually 10. Parsed as 11*<br>
# > *row 1202 : denominator is actually 10. Parsed as 50*<br>
# > *row 1165 : denominator is actually 10. Parsed as 20*<br>
# > *row 342 : date parsed as rating. No rating in sight*<br>
# > *row 313 : retweet of non-present tweet*<br>
# > *row 1663 : seems not to be a rating in fact*<br>
# > *row 2335 : denominator is actually 10. Parsed as 2*<br>
#
# There are multiple errors with these rating columns that arose from parsing. <br>
#
# I should remove the retweet and the row that seems not to be a rating
#
# I suspect there would be many more parsing errors since I only checked for tweets with low ratings. To further investigate these issues further, I will create a copy of the the dataframe to perform creating operations on.

# %%
# creating a copy dataframe
df_tweets_copy = df_tweets.copy()

# %%
pattern = "(\d+(\.\d+)?\/\d+(\.\d+)?)" # I found this regex pattern on StackOverflow; to extract the ratings fractions from text

# extracting ratings
df_tweets_copy['rating'] = df_tweets_copy['text'].str.extract(pattern, expand=True)[0]

# %%
# splitting by "/"
df_tweets_copy[['num', 'den']] = df_tweets_copy['rating'].str.split('/', n=1, expand=True)

# %%
# checking datatypes of corresponding columns
df_tweets_copy['num'].dtype
# Out:
# dtype('O')

# %%
# checking datatypes of corresponding columns
df_tweets_copy['rating_numerator'].dtype
# Out:
# dtype('int64')

# %%
# converting rating_numerator & rating_denominator to strings to enable comparison between columns
df_tweets_copy['rating_numerator'] = df_tweets_copy['rating_numerator'].astype("str")
df_tweets_copy['rating_denominator'] = df_tweets_copy['rating_denominator'].astype("str")

# %%
# checking for differences between original column and new extract
df_tweets_copy["num_check"] = df_tweets_copy[["rating_numerator", "num"]].apply(lambda x: False if (x[0] != x[1]) else True, axis = 1)

# %%
# sampling the columns
df_tweets_copy[['rating_numerator','num','num_check']].sample(10)
# Out:
#      rating_numerator num  num_check
# 622                12  12       True
# 1520                8   8       True
# 2096                9   9       True
# 1625               13  13       True
# 757                11  11       True
# 2069                8   8       True
# 2320                7   7       True
# 1758               10  10       True
# 1057                8   8       True
# 30                 12  12       True

# %%
# checking for the counts of incongruities
df_tweets_copy['num_check'].value_counts()
# Out:
# True     2349
# False       7
# Name: num_check, dtype: int64

# %% [markdown]
# So, there are 7 instances where the values I extracted is not equal to the original.<br>
# Exploring the differences...

# %%
mask = df_tweets_copy['num_check'] == False
df_tweets_copy[['rating_numerator','num','num_check']][mask]
# Out:
#      rating_numerator    num  num_check
# 45                  5   13.5      False
# 340                75   9.75      False
# 387                 7    007      False
# 695                75   9.75      False
# 763                27  11.27      False
# 1689                5    9.5      False
# 1712               26  11.26      False

# %% [markdown]
# This shows that the original dataframe extracted the mantissa as the numerator values.<br>
# Checking for the denominator as well...

# %%
# checking for differences between original column and new extract
df_tweets_copy["den_check"] = df_tweets_copy[["rating_denominator", "den"]].apply(lambda x: False if (x[0] != x[1]) else True, axis = 1)

# %%
# sampling the columns
df_tweets_copy[['rating_denominator','den','den_check']].sample(10)
# Out:
#      rating_denominator den  den_check
# 1708                 10  10       True
# 1800                 10  10       True
# 1888                 10  10       True
# 687                  10  10       True
# 720                  10  10       True
# 936                  10  10       True
# 1529                 10  10       True
# 2145                 10  10       True
# 977                  10  10       True
# 291                  10  10       True

# %%
# checking for the counts of incongruities
df_tweets_copy['den_check'].value_counts()
# Out:
# True     2355
# False       1
# Name: den_check, dtype: int64

# %%
mask = df_tweets_copy['den_check'] == False
df_tweets_copy[['rating_denominator','den','den_check']][mask]
# Out:
#     rating_denominator den  den_check
# 313                  0  00      False

# %% [markdown]
# I identified this row in my summary of parsing errors assessment, as a retweet of a non-present tweet; to be removed...<br>
# Now, I will check for tweets that have multiple fractions...as the extraction does not account for these cases

# %%
df_tweets_copy['no_of_ratings_per_tweet'] = df_tweets_copy['text'].str.count(pattern)

# %%
df_tweets_copy['no_of_ratings_per_tweet'].value_counts()
# Out:
# 1    2323
# 2      32
# 3       1
# Name: no_of_ratings_per_tweet, dtype: int64

# %%
# viewing tweets that don't have 1 rating
mask = df_tweets_copy['no_of_ratings_per_tweet'] != 1
df_tweets_copy[mask][['text','no_of_ratings_per_tweet']].head()
# Out:
#                                                   text  \
# 55   @roushfenway These are good dogs but 17/10 is ...
# 313  @jonnysun @Lin_Manuel ok jomny I know you're e...
# 561  RT @dog_rates: "Yep... just as I suspected. Yo...
# 766  "Yep... just as I suspected. You're not flossi...
# 784  RT @dog_rates: After so many requests, this is...
#
#      no_of_ratings_per_tweet
# 55                         2
# 313                        2
# 561                        2
# 766                        2
# 784                        2

# %%
df_tweets_copy[mask][['text','num','rating_numerator','no_of_ratings_per_tweet']]
# Out:
#                                                    text  num rating_numerator  \
# 55    @roushfenway These are good dogs but 17/10 is ...   17               17
# 313   @jonnysun @Lin_Manuel ok jomny I know you're e...  960              960
# 561   RT @dog_rates: "Yep... just as I suspected. Yo...   12               12
# 766   "Yep... just as I suspected. You're not flossi...   12               12
# 784   RT @dog_rates: After so many requests, this is...    9                9
# 860   RT @dog_rates: Meet Eve. She's a raging alcoho...    8                8
# 1007  This is Bookstore and Seaweed. Bookstore is ti...   10               10
# 1068  After so many requests, this is Bretagne. She ...    9                9
# 1165  Happy 4/20 from the squad! 13/10 for all https...    4                4
# 1202  This is Bluebert. He just saw that both #Final...   50               50
# 1222  Meet Travis and Flurp. Travis is pretty chill ...   10               10
# 1359  This is Socks. That water pup w the super legs...    9                9
# 1459  This may be the greatest video I've ever been ...    4                4
# 1465  Meet Oliviér. He takes killer selfies. Has a d...   10               10
# 1508  When bae says they can't go out but you see th...    5                5
# 1525  This is Eriq. His friend just reminded him of ...   10               10
# 1538  Meet Fynn &amp; Taco. Fynn is an all-powerful ...   11               11
# 1662  This is Darrel. He just robbed a 7/11 and is i...    7                7
# 1795  Meet Tassy &amp; Bee. Tassy is pretty chill, b...   10               10
# 1832  These two pups just met and have instantly bon...   10               10
# 1897  Meet Rufio. He is unaware of the pink legless ...   10               10
# 1901  Two gorgeous dogs here. Little waddling dog is...    5                5
# 1970  Meet Eve. She's a raging alcoholic 8/10 (would...    8                8
# 2010  10/10 for dog. 7/10 for cat. 12/10 for human. ...   10               10
# 2064  Meet Holly. She's trying to teach small human-...   11               11
# 2113  Meet Hank and Sully. Hank is very proud of the...   11               11
# 2177  Here we have Pancho and Peaches. Pancho is a C...   10               10
# 2216  This is Spark. He's nervous. Other dog hasn't ...    8                8
# 2263  This is Kial. Kial is either wearing a cape, w...   10               10
# 2272  Two dogs in this one. Both are rare Jujitsu Py...    7                7
# 2298  After much debate this dog is being upgraded t...   10               10
# 2306  These are Peruvian Feldspars. Their names are ...   10               10
# 2335  This is an Albanian 3 1/2 legged  Episcopalian...    1                1
#
#       no_of_ratings_per_tweet
# 55                          2
# 313                         2
# 561                         2
# 766                         2
# 784                         2
# 860                         2
# 1007                        2
# 1068                        2
# 1165                        2
# 1202                        2
# 1222                        2
# 1359                        2
# 1459                        2
# 1465                        2
# 1508                        2
# 1525                        2
# 1538                        2
# 1662                        2
# 1795                        2
# 1832                        2
# 1897                        2
# 1901                        2
# 1970                        2
# 2010                        3
# 2064                        2
# 2113                        2
# 2177                        2
# 2216                        2
# 2263                        2
# 2272                        2
# 2298                        2
# 2306                        2
# 2335                        2

# %% [markdown]
# For these rows, I will decide on the treatment on a case-by-case basis in the cleaning section

# %% [markdown]
# ----
# ### name, doggo, floofer, pupper, puppo

# %%
# checking value counts
df_tweets["name"].value_counts()
# Out:
# None          745
# a              55
# Charlie        12
# Cooper         11
# Lucy           11
#              ...
# Dex             1
# Ace             1
# Tayzie          1
# Grizzie         1
# Christoper      1
# Name: name, Length: 957, dtype: int64

# %%
df_tweets["doggo"].value_counts(normalize=True) * 100
# Out:
# None     95.882852
# doggo     4.117148
# Name: doggo, dtype: float64

# %%
# checking proportions of values
df_tweets["floofer"].value_counts(normalize=True) * 100
# Out:
# None       99.575552
# floofer     0.424448
# Name: floofer, dtype: float64

# %%
# checking proportions of values
df_tweets["pupper"].value_counts(normalize=True) * 100
# Out:
# None      89.091681
# pupper    10.908319
# Name: pupper, dtype: float64

# %%
# checking proportions of values
df_tweets["puppo"].value_counts(normalize=True) * 100
# Out:
# None     98.726655
# puppo     1.273345
# Name: puppo, dtype: float64

# %% [markdown]
# *There are 'None's in more than 90% of these rows overall*

# %%
df_tweets[['name']].sort_values(by='name').tail(60)
# Out:
#               name
# 2264             a
# 1004             a
# 1017             a
# 1785             a
# 2354             a
# 2198             a
# 1693      actually
# 1040      actually
# 1138           all
# 2333            an
# 2204            an
# 2349            an
# 2335            an
# 1025            an
# 1362            an
# 759             an
# 1724            by
# 1435       getting
# 1071       getting
# 992            his
# 542     incredibly
# 1259   infuriating
# 1457          just
# 2019          just
# 822           just
# 1063          just
# 1916          life
# 2001         light
# 1095           mad
# 682            mad
# 852             my
# 988            not
# 335            not
# 1747    officially
# 1206           old
# 993            one
# 1936           one
# 924            one
# 369            one
# 2326         quite
# 169          quite
# 118          quite
# 193          quite
# 2030         space
# 22            such
# 2345           the
# 2346           the
# 1603           the
# 2037           the
# 2212           the
# 1815           the
# 1797           the
# 1527           the
# 1120          this
# 1121  unacceptable
# 1031          very
# 773           very
# 1097          very
# 819           very
# 1385          very

# %% [markdown]
# *invalid names such as 'a', 'actually', 'all', 'an', ..., 'very' are present*

# %%
crit = df_tweets['name'] == 'None'
df_tweets[crit]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 5     891087950875897856                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# 24    887343217045368832                    NaN                  NaN
# 25    887101392804085760                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2342  666082916733198337                    NaN                  NaN
# 2343  666073100786774016                    NaN                  NaN
# 2344  666071193221509120                    NaN                  NaN
# 2351  666049248165822465                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 5     2017-07-29 00:08:17 +0000
# 7     2017-07-28 00:22:40 +0000
# 12    2017-07-25 01:55:32 +0000
# 24    2017-07-18 16:08:03 +0000
# 25    2017-07-18 00:07:08 +0000
# ...                         ...
# 2342  2015-11-16 02:38:37 +0000
# 2343  2015-11-16 01:59:36 +0000
# 2344  2015-11-16 01:52:02 +0000
# 2351  2015-11-16 00:24:50 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 5     <a href="http://twitter.com/download/iphone" r...
# 7     <a href="http://twitter.com/download/iphone" r...
# 12    <a href="http://twitter.com/download/iphone" r...
# 24    <a href="http://twitter.com/download/iphone" r...
# 25    <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2342  <a href="http://twitter.com/download/iphone" r...
# 2343  <a href="http://twitter.com/download/iphone" r...
# 2344  <a href="http://twitter.com/download/iphone" r...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 5     Here we have a majestic great white breaching ...                  NaN
# 7     When you watch your owner call another dog a g...                  NaN
# 12    Here's a puppo that seems to be on the fence a...                  NaN
# 24    You may not have known you needed to see this ...                  NaN
# 25    This... is a Jubilant Antarctic House Bear. We...                  NaN
# ...                                                 ...                  ...
# 2342  Here we have a well-established sunblockerspan...                  NaN
# 2343  Let's hope this flight isn't Malaysian (lol). ...                  NaN
# 2344  Here we have a northern speckled Rhododendron....                  NaN
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 5                          NaN                        NaN
# 7                          NaN                        NaN
# 12                         NaN                        NaN
# 24                         NaN                        NaN
# 25                         NaN                        NaN
# ...                        ...                        ...
# 2342                       NaN                        NaN
# 2343                       NaN                        NaN
# 2344                       NaN                        NaN
# 2351                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 5     https://twitter.com/dog_rates/status/891087950...                13
# 7     https://twitter.com/dog_rates/status/890729181...                13
# 12    https://twitter.com/dog_rates/status/889665388...                13
# 24    https://twitter.com/dog_rates/status/887343217...                13
# 25    https://twitter.com/dog_rates/status/887101392...                12
# ...                                                 ...               ...
# 2342  https://twitter.com/dog_rates/status/666082916...                 6
# 2343  https://twitter.com/dog_rates/status/666073100...                10
# 2344  https://twitter.com/dog_rates/status/666071193...                 9
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator  name doggo floofer pupper  puppo
# 5                     10  None  None    None   None   None
# 7                     10  None  None    None   None   None
# 12                    10  None  None    None   None  puppo
# 24                    10  None  None    None   None   None
# 25                    10  None  None    None   None   None
# ...                  ...   ...   ...     ...    ...    ...
# 2342                  10  None  None    None   None   None
# 2343                  10  None  None    None   None   None
# 2344                  10  None  None    None   None   None
# 2351                  10  None  None    None   None   None
# 2355                  10  None  None    None   None   None
#
# [745 rows x 17 columns]

# %%
# developing Boolean arrays to filter for dogs with no classifactions
crit_1 = df_tweets['doggo'] == 'None'
crit_2 = df_tweets['floofer'] == 'None'
crit_3 = df_tweets['pupper'] == 'None'
crit_4 = df_tweets['puppo'] == 'None'

crit_all = crit_1 & crit_2 & crit_3 & crit_4

# %%
# executing filter
df_tweets[['tweet_id','name', 'doggo', 'floofer', 'pupper', 'puppo']][crit_all].head()
# Out:
#              tweet_id      name doggo floofer pupper puppo
# 0  892420643555336193   Phineas  None    None   None  None
# 1  892177421306343426     Tilly  None    None   None  None
# 2  891815181378084864    Archie  None    None   None  None
# 3  891689557279858688     Darla  None    None   None  None
# 4  891327558926688256  Franklin  None    None   None  None

# %%
len(df_tweets[['tweet_id','name', 'doggo', 'floofer', 'pupper', 'puppo']][crit_all])
# Out:
# 1976

# %% [markdown]
# *There are 1976 dogs without classification*

# %% [markdown]
# ------
# -----
# **`2(a)`**<br>
# ## **Visual Assessment of `df_neural`**

# %%
# Visual assessment
df_neural.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %%
# Visual assessment
df_neural.tail()
# Out:
#                 tweet_id                                          jpg_url  \
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num           p1   p1_conf  p1_dog                  p2   p2_conf  \
# 2070        2       basset  0.555712    True    English_springer  0.225770
# 2071        1  paper_towel  0.170278   False  Labrador_retriever  0.168086
# 2072        1    Chihuahua  0.716012    True            malamute  0.078253
# 2073        1    Chihuahua  0.323581    True            Pekinese  0.090647
# 2074        1       orange  0.097049   False               bagel  0.085851
#
#       p2_dog                           p3   p3_conf  p3_dog
# 2070    True  German_short-haired_pointer  0.175219    True
# 2071    True                      spatula  0.040836   False
# 2072    True                       kelpie  0.031379    True
# 2073    True                     papillon  0.068957    True
# 2074   False                       banana  0.076110   False

# %%
# Visual assessment
df_neural.sample(5)
# Out:
#                 tweet_id                                          jpg_url  \
# 2045  886366144734445568  https://pbs.twimg.com/media/DE0BTnQUwAApKEH.jpg
# 259   670782429121134593  https://pbs.twimg.com/media/CU8ZDu9WwAADg3N.jpg
# 1627  804413760345620481  https://pbs.twimg.com/media/CuRDF-XWcAIZSer.jpg
# 1889  848324959059550208  https://pbs.twimg.com/media/C8XbDR1WAAAxND8.jpg
# 316   671743150407421952  https://pbs.twimg.com/media/CVKC1IfWIAAsQks.jpg
#
#       img_num              p1   p1_conf  p1_dog                p2   p2_conf  \
# 2045        1  French_bulldog  0.999201    True         Chihuahua  0.000361
# 259         1       Chihuahua  0.952963    True    French_bulldog  0.036575
# 1627        1            chow  0.090341    True        binoculars  0.083499
# 1889        1        malamute  0.544576    True    Siberian_husky  0.290268
# 316         1      toy_poodle  0.419427    True  miniature_poodle  0.237067
#
#       p2_dog            p3   p3_conf  p3_dog
# 2045    True   Boston_bull  0.000076    True
# 259     True   Boston_bull  0.001977    True
# 1627   False  Irish_setter  0.077456    True
# 1889    True    Eskimo_dog  0.154421    True
# 316     True         swing  0.104193   False

# %% [markdown]
# ------
# **`2(b)`**<br>
# ## **Programmatic Assessment of `df_neural`**

# %%
df_neural.shape
# Out:
# (2075, 12)

# %%
df_neural.columns
# Out:
# Index(['tweet_id', 'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2',
#        'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog'],
#       dtype='object')

# %%
df_neural.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
# calculating the number of nulls per column
df_neural.isna().sum()
# Out:
# tweet_id    0
# jpg_url     0
# img_num     0
# p1          0
# p1_conf     0
# p1_dog      0
# p2          0
# p2_conf     0
# p2_dog      0
# p3          0
# p3_conf     0
# p3_dog      0
# dtype: int64

# %%
# summary statistics
df_neural.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
# summary statistics for 'object' datatype
df_neural.describe(include='object')
# Out:
#                                                 jpg_url                p1  \
# count                                              2075              2075
# unique                                             2009               378
# top     https://pbs.twimg.com/media/CZhn-QAWwAASQan.jpg  golden_retriever
# freq                                                  2               150
#
#                         p2                  p3
# count                 2075                2075
# unique                 405                 408
# top     Labrador_retriever  Labrador_retriever
# freq                   104                  79

# %%
# checking for duplicates in the whole dataframe
df_neural[df_neural.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []

# %%
# checking for duplicates in the 'jpg_url'
df_neural[df_neural.duplicated(subset='jpg_url', keep=False)]
# Out:
#                 tweet_id                                          jpg_url  \
# 85    667509364010450944  https://pbs.twimg.com/media/CUN4Or5UAAAa5K4.jpg
# 224   670319130621435904  https://pbs.twimg.com/media/CU1zsMSUAAAS0qW.jpg
# 241   670444955656130560  https://pbs.twimg.com/media/CU3mITUWIAAfyQS.jpg
# 327   671896809300709376  https://pbs.twimg.com/media/CVMOlMiWwAA4Yxl.jpg
# 382   673320132811366400  https://pbs.twimg.com/media/CVgdFjNWEAAxmbq.jpg
# ...                  ...                                              ...
# 1970  868880397819494401  https://pbs.twimg.com/media/DA7iHL5U0AA1OQo.jpg
# 1992  873697596434513921  https://pbs.twimg.com/media/DA7iHL5U0AA1OQo.jpg
# 2041  885311592912609280  https://pbs.twimg.com/media/C4bTH6nWMAAX_bJ.jpg
# 2051  887473957103951883  https://pbs.twimg.com/media/DFDw2tyUQAAAFke.jpg
# 2055  888202515573088257  https://pbs.twimg.com/media/DFDw2tyUQAAAFke.jpg
#
#       img_num                  p1   p1_conf  p1_dog                   p2  \
# 85          1              beagle  0.636169    True   Labrador_retriever
# 224         1       Irish_terrier  0.254856    True               briard
# 241         1    English_springer  0.403698    True     Brittany_spaniel
# 327         1                chow  0.243529    True              hamster
# 382         3             Samoyed  0.978833    True           Pomeranian
# ...       ...                 ...       ...     ...                  ...
# 1970        1              laptop  0.153718   False       French_bulldog
# 1992        1              laptop  0.153718   False       French_bulldog
# 2041        1  Labrador_retriever  0.908703    True            seat_belt
# 2051        2            Pembroke  0.809197    True  Rhodesian_ridgeback
# 2055        2            Pembroke  0.809197    True  Rhodesian_ridgeback
#
#        p2_conf  p2_dog                           p3   p3_conf  p3_dog
# 85    0.119256    True             golden_retriever  0.082549    True
# 224   0.227716    True  soft-coated_wheaten_terrier  0.223263    True
# 241   0.347609    True       Welsh_springer_spaniel  0.137186    True
# 327   0.227150   False                   Pomeranian  0.056057    True
# 382   0.012763    True                   Eskimo_dog  0.001853    True
# ...        ...     ...                          ...       ...     ...
# 1970  0.099984    True                      printer  0.077130   False
# 1992  0.099984    True                      printer  0.077130   False
# 2041  0.057091   False                          pug  0.011933    True
# 2051  0.054950    True                       beagle  0.038915    True
# 2055  0.054950    True                       beagle  0.038915    True
#
# [132 rows x 12 columns]

# %% [markdown]
# *There are duplicates in the 'jpg_url' column. Probably retweets*

# %%
df_neural['p1'].value_counts()
# Out:
# golden_retriever      150
# Labrador_retriever    100
# Pembroke               89
# Chihuahua              83
# pug                    57
#                      ...
# pillow                  1
# carousel                1
# bald_eagle              1
# lorikeet                1
# orange                  1
# Name: p1, Length: 378, dtype: int64

# %%
mask = df_neural['p1_dog'] == False
df_neural[mask]
# Out:
#                 tweet_id                                            jpg_url  \
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 17    666104133288665088    https://pbs.twimg.com/media/CT56LSZWoAAlJj2.jpg
# 18    666268910803644416    https://pbs.twimg.com/media/CT8QCd1WEAADXws.jpg
# 21    666293911632134144    https://pbs.twimg.com/media/CT8mx7KW4AEQu8N.jpg
# ...                  ...                                                ...
# 2026  882045870035918850    https://pbs.twimg.com/media/DD2oCl2WAAEI_4a.jpg
# 2046  886680336477933568    https://pbs.twimg.com/media/DE4fEDzWAAAyHMM.jpg
# 2052  887517139158093824  https://pbs.twimg.com/ext_tw_video_thumb/88751...
# 2071  891689557279858688    https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2074  892420643555336193    https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                p1   p1_conf  p1_dog                  p2  \
# 6           1        box_turtle  0.933012   False          mud_turtle
# 8           1     shopping_cart  0.962465   False     shopping_basket
# 17          1               hen  0.965932   False                cock
# 18          1  desktop_computer  0.086502   False                desk
# 21          1  three-toed_sloth  0.914671   False               otter
# ...       ...               ...       ...     ...                 ...
# 2026        1          web_site  0.949591   False               dhole
# 2046        1       convertible  0.738995   False          sports_car
# 2052        1         limousine  0.130432   False           tow_truck
# 2071        1       paper_towel  0.170278   False  Labrador_retriever
# 2074        1            orange  0.097049   False               bagel
#
#        p2_conf  p2_dog                p3   p3_conf  p3_dog
# 6     0.045885   False          terrapin  0.017885   False
# 8     0.014594   False  golden_retriever  0.007959    True
# 17    0.033919   False         partridge  0.000052   False
# 18    0.085547   False          bookcase  0.079480   False
# 21    0.015250   False    great_grey_owl  0.013207   False
# ...        ...     ...               ...       ...     ...
# 2026  0.017326   False  golden_retriever  0.006941    True
# 2046  0.139952   False         car_wheel  0.044173   False
# 2052  0.029175   False     shopping_cart  0.026321   False
# 2071  0.168086    True           spatula  0.040836   False
# 2074  0.085851   False            banana  0.076110   False
#
# [543 rows x 12 columns]

# %%
# number of times the p1 prediction level does not predict dog
mask = df_neural['p2_dog'] == False
len(df_neural[mask])
# Out:
# 522

# %%
# number of times the p2 prediction level does not predict dog
mask = df_neural['p2_dog'] == False
len(df_neural[mask])
# Out:
# 522

# %%
# number of times the p3 prediction level does not predict dog
mask = df_neural['p3_dog'] == False
len(df_neural[mask])
# Out:
# 576

# %%
# checking to see whether the algorithm predicts if there is a dog or not at all prediction levels
df_neural[['p1', 'p2' ,'p3', 'p1_dog', 'p2_dog', 'p3_dog', 'p1_conf', 'p2_conf', 'p3_conf']].sample(5)
# Out:
#                     p1                  p2               p3  p1_dog  p2_dog  \
# 1359  Blenheim_spaniel      cocker_spaniel           borzoi    True    True
# 1477  golden_retriever  Labrador_retriever  Tibetan_mastiff    True    True
# 698            minibus               llama        seat_belt   False   False
# 453           seashore          promontory            wreck   False   False
# 1941   German_shepherd            Pembroke           muzzle    True    True
#
#       p3_dog   p1_conf   p2_conf   p3_conf
# 1359    True  0.113992  0.105780  0.073935
# 1477    True  0.628312  0.317365  0.012260
# 698    False  0.401942  0.229145  0.209393
# 453    False  0.352321  0.131753  0.095597
# 1941   False  0.507951  0.136113  0.075764

# %%
# checking for rows where the algorithm disagrees if there is a dog in the picture or not
crit_1 = df_neural['p1_dog'] != df_neural['p2_dog']
crit_2 = df_neural['p1_dog'] != df_neural['p3_dog']
crit_3 = df_neural['p2_dog'] != df_neural['p3_dog']
crit_all = crit_1 | crit_2 | crit_3
df_neural[['p1','p2','p3', 'jpg_url','p1_dog','p2_dog','p3_dog','p1_conf','p2_conf','p3_conf']][crit_all]
# Out:
#                             p1                  p2                p3  \
# 7                         chow     Tibetan_mastiff          fur_coat
# 8                shopping_cart     shopping_basket  golden_retriever
# 22                          ox        Newfoundland       groenendael
# 33                       llama       Irish_terrier             dingo
# 34    Chesapeake_Bay_retriever           chain_saw       power_drill
# ...                        ...                 ...               ...
# 2050          Mexican_hairless            sea_lion        Weimaraner
# 2063            French_bulldog  Labrador_retriever            muzzle
# 2068               Appenzeller       Border_collie         ice_lolly
# 2069  Chesapeake_Bay_retriever       Irish_terrier   Indian_elephant
# 2071               paper_towel  Labrador_retriever           spatula
#
#                                                 jpg_url  p1_dog  p2_dog  \
# 7       https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg    True    True
# 8       https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg   False   False
# 22      https://pbs.twimg.com/media/CT9OwFIWEAMuRje.jpg   False    True
# 33      https://pbs.twimg.com/media/CT-jNYqW4AAPi2M.jpg   False    True
# 34      https://pbs.twimg.com/media/CT-nsTQWEAEkyDn.jpg    True   False
# ...                                                 ...     ...     ...
# 2050  https://pbs.twimg.com/ext_tw_video_thumb/88734...    True   False
# 2063    https://pbs.twimg.com/media/DFl99B1WsAITKsg.jpg    True    True
# 2068    https://pbs.twimg.com/media/DF1eOmZXUAALUcq.jpg    True    True
# 2069    https://pbs.twimg.com/media/DF3HwyEWsAABqE6.jpg    True    True
# 2071    https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg   False    True
#
#       p3_dog   p1_conf   p2_conf   p3_conf
# 7      False  0.692517  0.058279  0.054449
# 8       True  0.962465  0.014594  0.007959
# 22      True  0.416669  0.278407  0.102643
# 33     False  0.505184  0.104109  0.062071
# 34     False  0.184130  0.056775  0.036763
# ...      ...       ...       ...       ...
# 2050    True  0.330741  0.275645  0.134203
# 2063   False  0.377417  0.151317  0.082981
# 2068   False  0.341703  0.199287  0.193548
# 2069   False  0.425595  0.116317  0.076902
# 2071   False  0.170278  0.168086  0.040836
#
# [508 rows x 10 columns]

# %% [markdown]
# *The algorithm is making some predictions that are not dogs*<br>
# *In 508 rows out of 2075 of the entire dataframe, the neural network disagrees about the content of the the image*<br>
#
# *Checking the pictures (via their urls), I see that some of the dogs are in the background, some pictures do not have dogs in them, or some dogs are in unsual positions or costume. That explains the unusual classifications*

# %% [markdown]
# ----
# ------
# **`3(a)`**<br>
# ### **Visual Assessment of `df_json`**

# %%
# Visual assessment
df_json.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           8287           37931
# 1  892177421306343426           6119           32575
# 2  891815181378084864           4054           24530
# 3  891689557279858688           8424           41274
# 4  891327558926688256           9128           39464

# %%
# Visual assessment
df_json.tail()
# Out:
#                 tweet_id  retweet_count  favorite_count
# 2335  666049248165822465             42             106
# 2336  666044226329800704            137             292
# 2337  666033412701032449             43             123
# 2338  666029285002620928             46             125
# 2339  666020888022790149            498            2530

# %%
# Visual assessment
df_json.sample(5)
# Out:
#                 tweet_id  retweet_count  favorite_count
# 638   792883833364439040           4682           12084
# 1515  690021994562220032           1101            2916
# 2138  669625907762618368           1852            3567
# 1905  674262580978937856            468            1328
# 1088  735256018284875776            941            3481

# %% [markdown]
# ------
# **`3(b)`**<br>
# ### **Programmatic Assessment of `df_json`**

# %%
df_json.shape
# Out:
# (2340, 3)

# %%
df_json.columns
# Out:
# Index(['tweet_id', 'retweet_count', 'favorite_count'], dtype='object')

# %%
df_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2340 entries, 0 to 2339
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2340 non-null   int64
#  1   retweet_count   2340 non-null   int64
#  2   favorite_count  2340 non-null   int64
# dtypes: int64(3)
# memory usage: 55.0 KB

# %%
# calculating the number of nulls per column
df_json.isna().sum()
# Out:
# tweet_id          0
# retweet_count     0
# favorite_count    0
# dtype: int64

# %%
# summary statistics
df_json.describe()
# Out:
#            tweet_id  retweet_count  favorite_count
# count  2.340000e+03    2340.000000     2340.000000
# mean   7.422176e+17    2917.531624     7940.355983
# std    6.832564e+16    4915.476215    12298.675488
# min    6.660209e+17       0.000000        0.000000
# 25%    6.783394e+17     584.750000     1370.750000
# 50%    7.186224e+17    1361.000000     3451.000000
# 75%    7.986954e+17    3398.000000     9720.000000
# max    8.924206e+17   83310.000000   163821.000000

# %%
# checking for duplicates
df_json[df_json.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [tweet_id, retweet_count, favorite_count]
# Index: []

# %% [markdown]
# *Looks clean*

# %% [markdown]
# <a id='assessingsum'></a>
# ## Assessing Summary
#
# **df_tweets**
# ### `Quality`<br>
# > - *the name column contain invalid values like 'a', 'None'*<br>
# > - *'None' is the most common value in the name column with a count of 745* <br>
# > - *From the heatmap, it is visible that in_reply_to_status_id and in_reply_to_user_id share rows with nans; retweeted_status_id, retweeted_status_user_id and*<br> *retweeted_status_timestamp also share rows with nans*
#
# > rating_numerator column:<br>
# > - *row 340 : numerator is actually 9.75. Parsed as 75*<br>
# > - *row 695 : numerator is actually 9.75. Parsed as 75 (Duplicate of row 340)*<br>
# > - *row 55 : numerator is actually 13. Parsed as 17*<br>
# > - *row 1712 : numerator is actually 11.26. Parsed as 26*<br>
# > - *row 1202 : numerator is actually 11. Parsed as 50*<br>
# > - *row 763 : numerator is actually 11.27. Parsed as 27*<br>
# > - *row  313 :  contains a retweet of a non-existent post. should be removed*<br>
# > - *row 2335 : numerator is actually 9. Parsed as 1*
#
# > rating_denominator column:<br>
# > - *row 784 : denominator is actually 10. Parsed as 11*<br>
# > - *row 1068 : seems to be a duplicate of row 784*<br>
# > - *row 1662 : denominator is actually 10. Parsed as 11*<br>
# > - *row 1202 : denominator is actually 10. Parsed as 50*<br>
# > - *row 1165 : denominator is actually 10. Parsed as 20*<br>
# > - *row 342 : date parsed as rating. No rating in sight*<br>
# > - *row 313 : retweet of non-present tweet*<br>
# > - *row 1663 : seems not to be a rating in fact*<br>
# > - *row 2335 : denominator is actually 10. Parsed as 2*<br>
#
# *There are 'None's in more than 90% of these rows overall*<br>
# *invalid names such as 'a', 'actually', 'all', 'an', ..., 'very' are present in the name column*<br>
# *There are 1976 dogs without classification i.e inputed as 'None'*<br>
# *incorrect extraction of ratings due to the text field containing multiple ratings*<br>
#
#
# ### `Tidiness`<br>
# > - redundant 'source' column
# > - variable names as column names e.g (doggo, floofer, pupper, puppo)
# > - timestamp is in object dtype; should be in timestamp
# > - in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id, and retweeted_status_timestamp values are mostly nans
# > - expanded_urls is 2.5% nans
# -----
#
# **df_neural**
# ### `Quality`<br>
# . . .
# ### `Tidiness`<br>
# > - *There are duplicates in the 'jpg_url' column. Probably retweets*
# > - *The algorithm is making some predictions that are not dogs. Perhaps the images are unclear*<br>
# > - *543 rows out of 2075 of the entire dataframe, are not dog predictions at the p1 level; 522 at the p2 level and 576 at the p3 level*<br>
# > - *The prediction columns should be collapsed*
# >
# > - *Checking the pictures (via their urls), I see that some of the dogs are in the background and some pictures do not have dogs in them. That explains the unusual classifications*
# ------
#
# **df_json**
# ### `Quality`<br>
# . . .
# ### `Tidiness`<br>
# . . .

# %% [markdown]
# <a id='assessing'></a>
# # `Clean`

# %%
# creating copies

df_tweets_clean = df_tweets.copy()
df_neural_clean = df_neural.copy()
df_json_clean = df_json.copy()

# %% [markdown]
# ### **tweets dataframe**

# %%
# before
print(f"Before merging, no. of tweets archive rows = {len(df_tweets_clean)}")
print(f"Before merging, no. of prediction dataset rows = {len(df_neural_clean)}")
print(f"Before merging, no. of api dataset rows = {len(df_json_clean)}")
# Out:
# Before merging, no. of tweets archive rows = 2356
# Before merging, no. of prediction dataset rows = 2075
# Before merging, no. of api dataset rows = 2340

# %%
# merging the dataframes together before cleaning sinnce they share common rows

# column to be merged on needs to be the index of the dataframes, to use .join method

df_tweets_clean.set_index('tweet_id', inplace=True)
df_neural_clean.set_index('tweet_id', inplace=True)
df_json_clean.set_index('tweet_id', inplace=True)

other = [df_neural_clean, df_json_clean]
df_join = df_tweets_clean.join(other, how='inner')

# %%
# inspecting
df_join.shape
# Out:
# (2067, 29)

# %%
df_join.columns
# Out:
# Index(['in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp', 'source',
#        'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo',
#        'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2', 'p2_conf',
#        'p2_dog', 'p3', 'p3_conf', 'p3_dog', 'retweet_count', 'favorite_count'],
#       dtype='object')

# %%
df_join.sample(7)
# Out:
#                     in_reply_to_status_id  in_reply_to_user_id  \
# tweet_id
# 692158366030913536                    NaN                  NaN
# 670778058496974848                    NaN                  NaN
# 747963614829678593                    NaN                  NaN
# 682032003584274432                    NaN                  NaN
# 759557299618865152                    NaN                  NaN
# 847962785489326080                    NaN                  NaN
# 750147208377409536                    NaN                  NaN
#
#                                     timestamp  \
# tweet_id
# 692158366030913536  2016-01-27 01:33:08 +0000
# 670778058496974848  2015-11-29 01:35:26 +0000
# 747963614829678593  2016-06-29 01:23:16 +0000
# 682032003584274432  2015-12-30 02:54:35 +0000
# 759557299618865152  2016-07-31 01:12:26 +0000
# 847962785489326080  2017-04-01 00:04:17 +0000
# 750147208377409536  2016-07-05 02:00:06 +0000
#
#                                                                source  \
# tweet_id
# 692158366030913536  <a href="http://twitter.com/download/iphone" r...
# 670778058496974848  <a href="http://twitter.com/download/iphone" r...
# 747963614829678593  <a href="http://twitter.com/download/iphone" r...
# 682032003584274432  <a href="http://twitter.com/download/iphone" r...
# 759557299618865152  <a href="http://twitter.com/download/iphone" r...
# 847962785489326080  <a href="http://twitter.com/download/iphone" r...
# 750147208377409536  <a href="http://twitter.com/download/iphone" r...
#
#                                                                  text  \
# tweet_id
# 692158366030913536  This is Edgar. He's a Sassafras Puggleflash. N...
# 670778058496974848  "To bone or not to bone?"\n10/10 https://t.co/...
# 747963614829678593  PUPPER NOOOOO BEHIND YOUUU 10/10 pls keep this...
# 682032003584274432  This is Ulysses. He likes holding hands and hi...
# 759557299618865152  This is Emma. She can't believe her last guess...
# 847962785489326080  This is Georgie. He's very shy. Only puppears ...
# 750147208377409536  And finally, happy 4th of July from the squad ...
#
#                     retweeted_status_id  retweeted_status_user_id  \
# tweet_id
# 692158366030913536                  NaN                       NaN
# 670778058496974848                  NaN                       NaN
# 747963614829678593                  NaN                       NaN
# 682032003584274432                  NaN                       NaN
# 759557299618865152                  NaN                       NaN
# 847962785489326080                  NaN                       NaN
# 750147208377409536                  NaN                       NaN
#
#                    retweeted_status_timestamp  \
# tweet_id
# 692158366030913536                        NaN
# 670778058496974848                        NaN
# 747963614829678593                        NaN
# 682032003584274432                        NaN
# 759557299618865152                        NaN
# 847962785489326080                        NaN
# 750147208377409536                        NaN
#
#                                                         expanded_urls  \
# tweet_id
# 692158366030913536  https://twitter.com/dog_rates/status/692158366...
# 670778058496974848  https://twitter.com/dog_rates/status/670778058...
# 747963614829678593  https://twitter.com/dog_rates/status/747963614...
# 682032003584274432  https://twitter.com/dog_rates/status/682032003...
# 759557299618865152  https://twitter.com/dog_rates/status/759557299...
# 847962785489326080  https://twitter.com/dog_rates/status/847962785...
# 750147208377409536  https://twitter.com/dog_rates/status/750147208...
#
#                     rating_numerator  ...   p1_conf p1_dog  \
# tweet_id                              ...
# 692158366030913536                10  ...  0.956565   True
# 670778058496974848                10  ...  0.776612   True
# 747963614829678593                10  ...  0.307672   True
# 682032003584274432                11  ...  0.997953   True
# 759557299618865152                10  ...  0.763333   True
# 847962785489326080                10  ...  0.882654  False
# 750147208377409536                13  ...  0.977765   True
#
#                                           p2   p2_conf p2_dog  \
# tweet_id
# 692158366030913536                     swing  0.018907  False
# 670778058496974848         Brabancon_griffon  0.112032   True
# 747963614829678593             Irish_terrier  0.197486   True
# 682032003584274432               groenendael  0.000676   True
# 759557299618865152  Chesapeake_Bay_retriever  0.194251   True
# 847962785489326080                      mink  0.066880  False
# 750147208377409536               Boston_bull  0.004794   True
#
#                                     p3   p3_conf  p3_dog retweet_count  \
# tweet_id
# 692158366030913536          toy_poodle  0.013544    True           843
# 670778058496974848               boxer  0.039051    True            74
# 747963614829678593               dingo  0.105475   False          2287
# 682032003584274432  miniature_pinscher  0.000211    True          2143
# 759557299618865152  Labrador_retriever  0.012225    True          1264
# 847962785489326080               otter  0.025679   False          5359
# 750147208377409536      French_bulldog  0.004573    True          1031
#
#                     favorite_count
# tweet_id
# 692158366030913536            2248
# 670778058496974848             331
# 747963614829678593            6059
# 682032003584274432            6876
# 759557299618865152            4958
# 847962785489326080           24286
# 750147208377409536            3258
#
# [7 rows x 29 columns]

# %%
# creating a copy of the merged dataframes
df_join_clean = df_join.copy()

# %% [markdown]
# ### ***Issue 1***: *Nulls*
# `df_join_clean`: There are NaNs in this DataFrame that need to be taken care of.
#
# ### ***Define***<br>
# Visualize the nulls, justify dropping them and then drop the offending columns if justification holds

# %% [markdown]
# ### ***Code***

# %%
# visualizing null values
fig, ax = plt.subplots(figsize = (20,7))
ax = sns.heatmap(df_join_clean.isnull(), vmin = 0, vmax = 1)

# %%
# checking % of nulls in these columns
df_join_clean[['in_reply_to_status_id',
               'in_reply_to_user_id',
               'retweeted_status_id',
               'retweeted_status_user_id',
               'retweeted_status_timestamp']].isnull().mean() * 100
# Out:
# in_reply_to_status_id         98.887276
# in_reply_to_user_id           98.887276
# retweeted_status_id           96.371553
# retweeted_status_user_id      96.371553
# retweeted_status_timestamp    96.371553
# dtype: float64

# %% [markdown]
# *All of these columns are largely nans so I am justified in dropping them*

# %%
columns_to_drop = ['in_reply_to_status_id',
               'in_reply_to_user_id',
               'retweeted_status_id',
               'retweeted_status_user_id',
               'retweeted_status_timestamp']

df_join_clean.drop(columns = columns_to_drop, inplace=True)

# %% [markdown]
# ### ***Test***

# %%
# checking whether the columns were dropped
columns_to_drop in df_join_clean.columns.to_list()
# Out:
# False

# %%
# visualizing
fig, ax = plt.subplots(figsize = (20,7))
ax = sns.heatmap(df_join_clean.isnull(), vmin = 0, vmax = 1)

# %%
df_join_clean.isnull().any().all()
# Out:
# False

# %% [markdown]
# ### ***Issue 2***: *Retweets*
# `df_join_clean`: Retweets are the cause of multiple images appearing in the dataframe
#
# ### ***Define***<br>
# Identify the retweets and remove them

# %% [markdown]
# ### ***Code***

# %%
# I identified the retweets by searching for duplicates on the 'jpg_url' column

mask = df_join_clean.duplicated(subset='jpg_url', keep='last')
df_join_clean[['text','jpg_url']][mask]
# Out:
#                                                                  text  \
# tweet_id
# 885311592912609280  RT @dog_rates: This is Lilly. She just paralle...
# 851953902622658560  RT @dog_rates: This is Astrid. She's a guide d...
# 841833993020538882  RT @dog_rates: This is Ken. His cheeks are mag...
# 832215726631055365  RT @dog_rates: This is Moreton. He's the Good ...
# 832040443403784192  RT @dog_rates: This is Klein. These pics were ...
# ...                                                               ...
# 759566828574212096  RT @dog_rates: This... is a Tyrannosaurus rex....
# 759159934323924993  RT @dog_rates: AT DAWN...\nWE RIDE\n\n11/10 ht...
# 757729163776290825  RT @dog_rates: This is Chompsky. He lives up t...
# 754874841593970688  RT @dog_rates: This is Rubio. He has too much ...
# 752309394570878976  RT @dog_rates: Everyone needs to watch this. 1...
#
#                                                               jpg_url
# tweet_id
# 885311592912609280    https://pbs.twimg.com/media/C4bTH6nWMAAX_bJ.jpg
# 851953902622658560    https://pbs.twimg.com/media/C4KHj-nWQAA3poV.jpg
# 841833993020538882  https://pbs.twimg.com/ext_tw_video_thumb/81742...
# 832215726631055365    https://pbs.twimg.com/media/CwJR1okWIAA6XMp.jpg
# 832040443403784192    https://pbs.twimg.com/media/Cq9guJ5WgAADfpF.jpg
# ...                                                               ...
# 759566828574212096    https://pbs.twimg.com/media/CkNjahBXAAQ2kWo.jpg
# 759159934323924993    https://pbs.twimg.com/media/CU1zsMSUAAAS0qW.jpg
# 757729163776290825    https://pbs.twimg.com/media/CWyD2HGUYAQ1Xa7.jpg
# 754874841593970688    https://pbs.twimg.com/media/CWza7kpWcAAdYLc.jpg
# 752309394570878976  https://pbs.twimg.com/ext_tw_video_thumb/67535...
#
# [61 rows x 2 columns]

# %%
# selecting rows to drop
rows_to_drop = df_join_clean[['text','jpg_url']][mask].index

# dropping the rows
df_join_clean.drop(rows_to_drop, inplace=True)

# %% [markdown]
# ### ***Test***

# %%
# checking the new shape
df_join_clean.shape
# Out:
# (2006, 24)

# %%
# checking for duplicates
mask = df_join_clean.duplicated(subset='jpg_url', keep=False)
df_join_clean[['text','jpg_url']][mask]
# Out:
# Empty DataFrame
# Columns: [text, jpg_url]
# Index: []

# %% [markdown]
# ### ***Issue 3***: *Wrong datatype of timestamp column*
# `df_join_clean`: timestamp column needs to be converted
#
# ### ***Define***<br>
# Check for the datatype of the timestamp column and convert it to a datetime column

# %% [markdown]
# ### ***Code***

# %%
# checking for datatype of the timestamp column
df_join_clean.timestamp.dtype
# Out:
# dtype('O')

# %%
# converting to datetime
df_join_clean['timestamp'] = pd.to_datetime(df_join_clean['timestamp'])

# %% [markdown]
# ### ***Test***

# %%
df_join_clean['timestamp'].dtype
# Out:
# datetime64[ns, UTC]

# %% [markdown]
# ### ***Issue 4***: *Source column HTML codes*
# `df_join_clean`: Between the `<a></a>` tags in the `source` column lies information about the tweets source
#
# ### ***Define***<br>
# Check source column and use a regex pattern to extract the content between the tags

# %% [markdown]
# ### ***Code***

# %%
# checking ...
pd.set_option('display.max_colwidth', 250)
df_join_clean[['source']].sample(5)
# Out:
#                                                                                                 source
# tweet_id
# 696900204696625153  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 697255105972801536  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 748932637671223296  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 667546741521195010                  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 750117059602808832  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>

# %%
# extracting the contents between the <a></a> tags in the source column
df_join_clean['source'] = df_join_clean.source.str.extract("\>(.*?)\<", expand = True)

# %% [markdown]
# ### ***Test***

# %%
# checking ...
df_join_clean['source'].value_counts()
# Out:
# Twitter for iPhone    1966
# Twitter Web Client      30
# TweetDeck               10
# Name: source, dtype: int64

# %% [markdown]
# -------
# ### ***Issue 5***: *Dealing with incorrect numerator and denominator ratings*
# `df_join_clean`: As a result of parsing errors (revealed in the assessment section), some of the numerator and denominator values are not correct
#
# ### ***Define***<br>
# Extract fractions from the text column and split by "/". Then treat on a case-by-case basis for exceptions

# %%
df_join_clean[['text']].sample(2)
# Out:
#                                                                                                                                                               text
# tweet_id
# 667165590075940865         This is Churlie. AKA Fetty Woof. Lost eye saving a school bus full of toddlers from a tsunami. Great guy. 10/10 https://t.co/li2XYBVuAY
# 785170936622350336  This is Hero. He was enjoying the car ride until he remembered that bees are dying globally at an alarming rate. 11/10 https://t.co/cubFg7F4qQ

# %% [markdown]
# ### ***Code***

# %%
pattern = "(\d+(\.\d+)?\/\d+(\.\d+)?)"

# extracting ratings using regex
df_join_clean['rating'] = df_join_clean['text'].str.extract(pattern, expand=True)[0]

# %%
# splitting by "/"
df_join_clean[['num', 'den']] = df_join_clean['rating'].str.split('/', n=1, expand=True)

# %%
# getting the number of fractions i.e ratings occurring in the text body
df_join_clean['no_of_ratings_per_tweet'] = df_join_clean['text'].str.count(pattern)

# %%
# aggregating counts of times fractions appear
df_join_clean['no_of_ratings_per_tweet'].value_counts()
# Out:
# 1    1979
# 2      26
# 3       1
# Name: no_of_ratings_per_tweet, dtype: int64

# %% [markdown]
# *There are 27 rows with more than 1 rating. Checking for these...*

# %%
# viewing tweets that don't have 1 rating
mask = df_join_clean['no_of_ratings_per_tweet'] != 1
df_join_clean[mask][['text','no_of_ratings_per_tweet']]
# Out:
#                                                                                                                                                                    text  \
# tweet_id
# 777684233540206592                                  "Yep... just as I suspected. You're not flossing." 12/10 and 11/10 for the pup not flossing https://t.co/SuXcI9B7pQ
# 747600769478692864                     This is Bookstore and Seaweed. Bookstore is tired and Seaweed is an asshole. 10/10 and 7/10 respectively https://t.co/eUGjGjjFVJ
# 740373189193256964         After so many requests, this is Bretagne. She was the last surviving 9/11 search dog, and our second ever 14/10. RIP https://t.co/XAVDNDaVgQ
# 722974582966214656                                                                                     Happy 4/20 from the squad! 13/10 for all https://t.co/eV1diwds8a
# 716439118184652801                                This is Bluebert. He just saw that both #FinalFur match ups are split 50/50. Amazed af. 11/10 https://t.co/Kky1DPG4iq
# 714258258790387713     Meet Travis and Flurp. Travis is pretty chill but Flurp can't lie down properly. 10/10 &amp; 8/10\nget it together Flurp https://t.co/Akzl5ynMmE
# 703356393781329922               This is Socks. That water pup w the super legs just splashed him. Socks did not appreciate that. 9/10 and 2/10 https://t.co/8rc5I22bBf
# 695064344191721472           This may be the greatest video I've ever been sent. 4/10 for Charles the puppy, 13/10 overall. (Vid by @stevenxx_) https://t.co/uaJmNgXR2P
# 694352839993344000  Meet Oliviér. He takes killer selfies. Has a dog of his own. It leaps at random &amp; can't bark for shit. 10/10 &amp; 5/10 https://t.co/6NgsQJuSBJ
# 691483041324204033     When bae says they can't go out but you see them with someone else that same night. 5/10 &amp; 10/10 for heartbroken pup https://t.co/aenk0KpoWM
# 690400367696297985       This is Eriq. His friend just reminded him of last year's super bowl. Not cool friend\n10/10 for Eriq\n6/10 for friend https://t.co/PlEXTofdpf
# 689835978131935233  Meet Fynn &amp; Taco. Fynn is an all-powerful leaf lord and Taco is in the wrong place at the wrong time. 11/10 &amp; 10/10 https://t.co/MuqHPvtL8c
# 682962037429899265          This is Darrel. He just robbed a 7/11 and is in a high speed police chase. Was just spotted by the helicopter 10/10 https://t.co/7EsP8LmSp5
# 677314812125323265    Meet Tassy &amp; Bee. Tassy is pretty chill, but Bee is convinced the Ruffles are haunted. 10/10 &amp; 11/10 respectively https://t.co/fgORpmTN9C
# 676191832485810177            These two pups just met and have instantly bonded. Spectacular scene. Mesmerizing af. 10/10 and 7/10 for blue dog https://t.co/gwryaJO4tC
# 674737130913071104     Meet Rufio. He is unaware of the pink legless pupper wrapped around him. Might want to get that checked 10/10 &amp; 4/10 https://t.co/KNfLnYPmYh
# 674646392044941312        Two gorgeous dogs here. Little waddling dog is a rebel. Refuses to look at camera. Must be a preteen. 5/10 &amp; 8/10 https://t.co/YPfw7oahbD
# 673295268553605120         Meet Eve. She's a raging alcoholic 8/10 (would b 11/10 but pupper alcoholism is a tragic issue that I can't condone) https://t.co/U36HYQIijg
# 672248013293752320                                                      10/10 for dog. 7/10 for cat. 12/10 for human. Much skill. Would pet all https://t.co/uhx5gfpx5k
# 671154572044468225      Meet Holly. She's trying to teach small human-like pup about blocks but he's not paying attention smh. 11/10 &amp; 8/10 https://t.co/RcksaUrGNu
# 670434127938719744              Meet Hank and Sully. Hank is very proud of the pumpkin they found and Sully doesn't give a shit. 11/10 and 8/10 https://t.co/cwoP1ftbrj
# 669037058363662336        Here we have Pancho and Peaches. Pancho is a Condoleezza Gryffindor, and Peaches is just an asshole. 10/10 &amp; 7/10 https://t.co/Lh1BsJrWPp
# 668537837512433665     This is Spark. He's nervous. Other dog hasn't moved in a while. Won't come when called. Doesn't fetch well 8/10&amp;1/10 https://t.co/stEodX9Aba
# 667544320556335104          This is Kial. Kial is either wearing a cape, which would be rad, or flashing us, which would be rude. 10/10 or 4/10 https://t.co/8zcwIoiuqR
# 667491009379606528           Two dogs in this one. Both are rare Jujitsu Pythagoreans. One slightly whiter than other. Long legs. 7/10 and 8/10 https://t.co/ITxxcc4v9y
# 666835007768551424     These are Peruvian Feldspars. Their names are Cupit and Prencer. Both resemble Rand Paul. Sick outfits 10/10 &amp; 10/10 https://t.co/ZnEMHBsAs1
# 666287406224695296             This is an Albanian 3 1/2 legged  Episcopalian. Loves well-polished hardwood flooring. Penis on the collar. 9/10 https://t.co/d9NcXFKwLv
#
#                     no_of_ratings_per_tweet
# tweet_id
# 777684233540206592                        2
# 747600769478692864                        2
# 740373189193256964                        2
# 722974582966214656                        2
# 716439118184652801                        2
# 714258258790387713                        2
# 703356393781329922                        2
# 695064344191721472                        2
# 694352839993344000                        2
# 691483041324204033                        2
# 690400367696297985                        2
# 689835978131935233                        2
# 682962037429899265                        2
# 677314812125323265                        2
# 676191832485810177                        2
# 674737130913071104                        2
# 674646392044941312                        2
# 673295268553605120                        2
# 672248013293752320                        3
# 671154572044468225                        2
# 670434127938719744                        2
# 669037058363662336                        2
# 668537837512433665                        2
# 667544320556335104                        2
# 667491009379606528                        2
# 666835007768551424                        2
# 666287406224695296                        2

# %% [markdown]
# *I will manually extract ratings for these on a case by case basis...*

# %%
# assigning index of these rows to a variable so I can assess the index one by one
multiple_ratings = df_join_clean[mask][['text','no_of_ratings_per_tweet']].index.to_list()

# %% [markdown]
# *Below, I use some print statements to clarify the process*<br>
# *I wrote some functions to minimize code repetition...*

# %%
# start
a = 0

# %%
def print_text():
    """"
    Returns the text containing dog ratings for a specified tweet_id
    """
    print(f"Case {a + 1}:\n")
    return df_join_clean[['text','no_of_ratings_per_tweet']].loc[multiple_ratings[a]]

#################

def print_incorrect_num():
    """
    Returns original, incorrect numerator
    """
    print(f"Case {a + 1}: incorrect numerator = {df_join_clean.loc[multiple_ratings[a]]['num']}")

#################

def correct_rating(nval, dval):
    """
    Overwrites incorrect numerator and denominator
    PARAMETER: nval = value of correct rating numerator
    PARAMETER: dval = value of correct rating denominator
    """
    print(f"Before correction: rating = {df_join_clean.loc[multiple_ratings[a]]['num']}/{df_join_clean.loc[multiple_ratings[a]]['den']}")

    print(f"\n\tCORRECTING TWEET_ID {multiple_ratings[a]} ...")

    # code
    df_join_clean.loc[multiple_ratings[a], 'num'] = str(nval)
    df_join_clean.loc[multiple_ratings[a], 'den'] = str(dval)


    # test
    print(f"\nAfter correction: rating = {df_join_clean.loc[multiple_ratings[a]]['num']}/{df_join_clean.loc[multiple_ratings[a]]['den']}")

#################

# %%
# check
print_text()
# Out:
# Case 1:
# text                       "Yep... just as I suspected. You're not flossing." 12/10 and 11/10 for the pup not flossing https://t.co/SuXcI9B7pQ
# no_of_ratings_per_tweet                                                                                                                      2
# Name: 777684233540206592, dtype: object

# %%
df_join_clean.loc[multiple_ratings[a]]['num']
# Checking the text, either of the ratings could hold so I'll just leave as is
# Out:
# '12'

# %%
# check
a = 1
print_text()
# Out:
# Case 2:
# text                       This is Bookstore and Seaweed. Bookstore is tired and Seaweed is an asshole. 10/10 and 7/10 respectively https://t.co/eUGjGjjFVJ
# no_of_ratings_per_tweet                                                                                                                                   2
# Name: 747600769478692864, dtype: object

# %%
# This is a case of two dogs in one picture. I decide to pick the average of the two ratings
correct_rating(8.5, 10)
# Out:
# Before correction: rating = 10/10
#
# 	CORRECTING TWEET_ID 747600769478692864 ...
#
# After correction: rating = 8.5/10

# %% [markdown]
# *moving on ....*

# %%
# check
a = 2
print_text()
# Out:
# Case 3:
# text                       After so many requests, this is Bretagne. She was the last surviving 9/11 search dog, and our second ever 14/10. RIP https://t.co/XAVDNDaVgQ
# no_of_ratings_per_tweet                                                                                                                                               2
# Name: 740373189193256964, dtype: object

# %%
# In this case, the second fraction is the correct rating
correct_rating(14, 10)
# Out:
# Before correction: rating = 9/11
#
# 	CORRECTING TWEET_ID 740373189193256964 ...
#
# After correction: rating = 14/10

# %% [markdown]
# *Moving on...*

# %%
# check
a = 3
print_text()
# Out:
# Case 4:
# text                       Happy 4/20 from the squad! 13/10 for all https://t.co/eV1diwds8a
# no_of_ratings_per_tweet                                                                   2
# Name: 722974582966214656, dtype: object

# %%
# In this case, the second fraction is the correct rating
print_incorrect_num()
# Out:
# Case 4: incorrect numerator = 4

# %%
correct_rating(13, 10)
# Out:
# Before correction: rating = 4/20
#
# 	CORRECTING TWEET_ID 722974582966214656 ...
#
# After correction: rating = 13/10

# %% [markdown]
# *next...*

# %%
# check
a = 4
print_text()
# Out:
# Case 5:
# text                       This is Bluebert. He just saw that both #FinalFur match ups are split 50/50. Amazed af. 11/10 https://t.co/Kky1DPG4iq
# no_of_ratings_per_tweet                                                                                                                        2
# Name: 716439118184652801, dtype: object

# %%
# In this case, the second fraction is the correct rating
correct_rating(11, 10)
# Out:
# Before correction: rating = 50/50
#
# 	CORRECTING TWEET_ID 716439118184652801 ...
#
# After correction: rating = 11/10

# %% [markdown]
# *Next...*

# %%
# check
a = 5
print_text()
# Out:
# Case 6:
# text                       Meet Travis and Flurp. Travis is pretty chill but Flurp can't lie down properly. 10/10 &amp; 8/10\nget it together Flurp https://t.co/Akzl5ynMmE
# no_of_ratings_per_tweet                                                                                                                                                   2
# Name: 714258258790387713, dtype: object

# %%
# In this case, I will take the average of the two (avg(10,8) = 9) as the numerator
correct_rating(9, 10)
# Out:
# Before correction: rating = 10/10
#
# 	CORRECTING TWEET_ID 714258258790387713 ...
#
# After correction: rating = 9/10

# %% [markdown]
# *Next...*

# %%
# check
a = 6
print_text()
# Out:
# Case 7:
# text                       This is Socks. That water pup w the super legs just splashed him. Socks did not appreciate that. 9/10 and 2/10 https://t.co/8rc5I22bBf
# no_of_ratings_per_tweet                                                                                                                                         2
# Name: 703356393781329922, dtype: object

# %%
# I believe Socks is a 9/10
correct_rating(9, 10)
# Out:
# Before correction: rating = 9/10
#
# 	CORRECTING TWEET_ID 703356393781329922 ...
#
# After correction: rating = 9/10

# %% [markdown]
# *Next...*

# %%
# check
a = 7
print_text()
# Out:
# Case 8:
# text                       This may be the greatest video I've ever been sent. 4/10 for Charles the puppy, 13/10 overall. (Vid by @stevenxx_) https://t.co/uaJmNgXR2P
# no_of_ratings_per_tweet                                                                                                                                             2
# Name: 695064344191721472, dtype: object

# %%
# This situtation is unclear so I pick 13/10 here
correct_rating(13,10)
# Out:
# Before correction: rating = 4/10
#
# 	CORRECTING TWEET_ID 695064344191721472 ...
#
# After correction: rating = 13/10

# %%
# check
a = 8
print_text()
# Out:
# Case 9:
# text                       Meet Oliviér. He takes killer selfies. Has a dog of his own. It leaps at random &amp; can't bark for shit. 10/10 &amp; 5/10 https://t.co/6NgsQJuSBJ
# no_of_ratings_per_tweet                                                                                                                                                      2
# Name: 694352839993344000, dtype: object

# %%
# Taking the average: 5/10
correct_rating(5,10)
# Out:
# Before correction: rating = 10/10
#
# 	CORRECTING TWEET_ID 694352839993344000 ...
#
# After correction: rating = 5/10

# %%
# check
a = 9
print_text()
# Out:
# Case 10:
# text                       When bae says they can't go out but you see them with someone else that same night. 5/10 &amp; 10/10 for heartbroken pup https://t.co/aenk0KpoWM
# no_of_ratings_per_tweet                                                                                                                                                   2
# Name: 691483041324204033, dtype: object

# %%
correct_rating(5,10)
# Out:
# Before correction: rating = 5/10
#
# 	CORRECTING TWEET_ID 691483041324204033 ...
#
# After correction: rating = 5/10

# %%
# check
a = 10
print_text()
# Out:
# Case 11:
# text                       This is Eriq. His friend just reminded him of last year's super bowl. Not cool friend\n10/10 for Eriq\n6/10 for friend https://t.co/PlEXTofdpf
# no_of_ratings_per_tweet                                                                                                                                                 2
# Name: 690400367696297985, dtype: object

# %%
# Taking the average : avg(10,6) = 8
correct_rating(8, 10)
# Out:
# Before correction: rating = 10/10
#
# 	CORRECTING TWEET_ID 690400367696297985 ...
#
# After correction: rating = 8/10

# %%
# check
a = 11
print_text()
# Out:
# Case 12:
# text                       Meet Fynn &amp; Taco. Fynn is an all-powerful leaf lord and Taco is in the wrong place at the wrong time. 11/10 &amp; 10/10 https://t.co/MuqHPvtL8c
# no_of_ratings_per_tweet                                                                                                                                                      2
# Name: 689835978131935233, dtype: object

# %%
correct_rating(10.5, 10)
# Out:
# Before correction: rating = 11/10
#
# 	CORRECTING TWEET_ID 689835978131935233 ...
#
# After correction: rating = 10.5/10

# %%
# check
a = 12
print_text()
# Out:
# Case 13:
# text                       This is Darrel. He just robbed a 7/11 and is in a high speed police chase. Was just spotted by the helicopter 10/10 https://t.co/7EsP8LmSp5
# no_of_ratings_per_tweet                                                                                                                                              2
# Name: 682962037429899265, dtype: object

# %%
# code & test
# correct rating = 10/10
correct_rating(10,10)
# Out:
# Before correction: rating = 7/11
#
# 	CORRECTING TWEET_ID 682962037429899265 ...
#
# After correction: rating = 10/10

# %%
# check
a = 13
print_text()
# Out:
# Case 14:
# text                       Meet Tassy &amp; Bee. Tassy is pretty chill, but Bee is convinced the Ruffles are haunted. 10/10 &amp; 11/10 respectively https://t.co/fgORpmTN9C
# no_of_ratings_per_tweet                                                                                                                                                    2
# Name: 677314812125323265, dtype: object

# %%
# code & test
# correct rating = average = 10.5/10
correct_rating(10.5,10)
# Out:
# Before correction: rating = 10/10
#
# 	CORRECTING TWEET_ID 677314812125323265 ...
#
# After correction: rating = 10.5/10

# %%
# check
a = 14
print_text()
# Out:
# Case 15:
# text                       These two pups just met and have instantly bonded. Spectacular scene. Mesmerizing af. 10/10 and 7/10 for blue dog https://t.co/gwryaJO4tC
# no_of_ratings_per_tweet                                                                                                                                            2
# Name: 676191832485810177, dtype: object

# %%
# code & test
# correct rating = average = 8.5/10
correct_rating(8.5,10)
# Out:
# Before correction: rating = 10/10
#
# 	CORRECTING TWEET_ID 676191832485810177 ...
#
# After correction: rating = 8.5/10

# %%
# check
a = 15
print_text()
# Out:
# Case 16:
# text                       Meet Rufio. He is unaware of the pink legless pupper wrapped around him. Might want to get that checked 10/10 &amp; 4/10 https://t.co/KNfLnYPmYh
# no_of_ratings_per_tweet                                                                                                                                                   2
# Name: 674737130913071104, dtype: object

# %%
# code & test
# correct rating = average = 7/10
correct_rating(7,10)
# Out:
# Before correction: rating = 10/10
#
# 	CORRECTING TWEET_ID 674737130913071104 ...
#
# After correction: rating = 7/10

# %%
# check
a = 16
print_text()
# Out:
# Case 17:
# text                       Two gorgeous dogs here. Little waddling dog is a rebel. Refuses to look at camera. Must be a preteen. 5/10 &amp; 8/10 https://t.co/YPfw7oahbD
# no_of_ratings_per_tweet                                                                                                                                                2
# Name: 674646392044941312, dtype: object

# %%
# code & test
# correct rating = average = 6.5/10
correct_rating(6.5,10)
# Out:
# Before correction: rating = 5/10
#
# 	CORRECTING TWEET_ID 674646392044941312 ...
#
# After correction: rating = 6.5/10

# %%
# check
a = 17
print_text()
# Out:
# Case 18:
# text                       Meet Eve. She's a raging alcoholic 8/10 (would b 11/10 but pupper alcoholism is a tragic issue that I can't condone) https://t.co/U36HYQIijg
# no_of_ratings_per_tweet                                                                                                                                               2
# Name: 673295268553605120, dtype: object

# %%
# code & test
# correct rating =  8/10
correct_rating(8,10)
# Out:
# Before correction: rating = 8/10
#
# 	CORRECTING TWEET_ID 673295268553605120 ...
#
# After correction: rating = 8/10

# %%
# check
a = 18
print_text()
# Out:
# Case 19:
# text                       10/10 for dog. 7/10 for cat. 12/10 for human. Much skill. Would pet all https://t.co/uhx5gfpx5k
# no_of_ratings_per_tweet                                                                                                  3
# Name: 672248013293752320, dtype: object

# %%
# code & test
# correct rating =  10/10
correct_rating(10,10)
# Out:
# Before correction: rating = 10/10
#
# 	CORRECTING TWEET_ID 672248013293752320 ...
#
# After correction: rating = 10/10

# %%
# check
a = 19
print_text()
# Out:
# Case 20:
# text                       Meet Holly. She's trying to teach small human-like pup about blocks but he's not paying attention smh. 11/10 &amp; 8/10 https://t.co/RcksaUrGNu
# no_of_ratings_per_tweet                                                                                                                                                  2
# Name: 671154572044468225, dtype: object

# %%
# code & test
# correct rating = average = 9.5/10
correct_rating(9.5,10)
# Out:
# Before correction: rating = 11/10
#
# 	CORRECTING TWEET_ID 671154572044468225 ...
#
# After correction: rating = 9.5/10

# %%
# check
a = 20
print_text()
# Out:
# Case 21:
# text                       Meet Hank and Sully. Hank is very proud of the pumpkin they found and Sully doesn't give a shit. 11/10 and 8/10 https://t.co/cwoP1ftbrj
# no_of_ratings_per_tweet                                                                                                                                          2
# Name: 670434127938719744, dtype: object

# %%
# code & test
# correct rating = average = 9.5/10
correct_rating(9.5,10)
# Out:
# Before correction: rating = 11/10
#
# 	CORRECTING TWEET_ID 670434127938719744 ...
#
# After correction: rating = 9.5/10

# %%
# check
a = 21
print_text()
# Out:
# Case 22:
# text                       Here we have Pancho and Peaches. Pancho is a Condoleezza Gryffindor, and Peaches is just an asshole. 10/10 &amp; 7/10 https://t.co/Lh1BsJrWPp
# no_of_ratings_per_tweet                                                                                                                                                2
# Name: 669037058363662336, dtype: object

# %%
# code & test
# correct rating = average = 8.5/10
correct_rating(8.5,10)
# Out:
# Before correction: rating = 10/10
#
# 	CORRECTING TWEET_ID 669037058363662336 ...
#
# After correction: rating = 8.5/10

# %%
# check
a = 22
print_text()
# Out:
# Case 23:
# text                       This is Spark. He's nervous. Other dog hasn't moved in a while. Won't come when called. Doesn't fetch well 8/10&amp;1/10 https://t.co/stEodX9Aba
# no_of_ratings_per_tweet                                                                                                                                                   2
# Name: 668537837512433665, dtype: object

# %%
# code & test
# correct rating = average = 4.5/10
correct_rating(4.5,10)
# Out:
# Before correction: rating = 8/10
#
# 	CORRECTING TWEET_ID 668537837512433665 ...
#
# After correction: rating = 4.5/10

# %%
# check
a = 23
print_text()
# Out:
# Case 24:
# text                       This is Kial. Kial is either wearing a cape, which would be rad, or flashing us, which would be rude. 10/10 or 4/10 https://t.co/8zcwIoiuqR
# no_of_ratings_per_tweet                                                                                                                                              2
# Name: 667544320556335104, dtype: object

# %%
# code & test
# I arbitrarily choose the choose the highest rating = 10/10
correct_rating(10,10)
# Out:
# Before correction: rating = 10/10
#
# 	CORRECTING TWEET_ID 667544320556335104 ...
#
# After correction: rating = 10/10

# %%
# check
a = 24
print_text()
# Out:
# Case 25:
# text                       Two dogs in this one. Both are rare Jujitsu Pythagoreans. One slightly whiter than other. Long legs. 7/10 and 8/10 https://t.co/ITxxcc4v9y
# no_of_ratings_per_tweet                                                                                                                                             2
# Name: 667491009379606528, dtype: object

# %%
# code & test
# correct rating = average = 7.5/10
correct_rating(7.5,10)
# Out:
# Before correction: rating = 7/10
#
# 	CORRECTING TWEET_ID 667491009379606528 ...
#
# After correction: rating = 7.5/10

# %%
# check
a = 25
print_text()
# Out:
# Case 26:
# text                       These are Peruvian Feldspars. Their names are Cupit and Prencer. Both resemble Rand Paul. Sick outfits 10/10 &amp; 10/10 https://t.co/ZnEMHBsAs1
# no_of_ratings_per_tweet                                                                                                                                                   2
# Name: 666835007768551424, dtype: object

# %%
# code & test
# correct rating = average = 10/10
correct_rating(10,10)
# Out:
# Before correction: rating = 10/10
#
# 	CORRECTING TWEET_ID 666835007768551424 ...
#
# After correction: rating = 10/10

# %%
# last check
a = 26
print_text()
# Out:
# Case 27:
# text                       This is an Albanian 3 1/2 legged  Episcopalian. Loves well-polished hardwood flooring. Penis on the collar. 9/10 https://t.co/d9NcXFKwLv
# no_of_ratings_per_tweet                                                                                                                                           2
# Name: 666287406224695296, dtype: object

# %%
# code & test
# correct rating = 9/10
correct_rating(9,10)
# Out:
# Before correction: rating = 1/2
#
# 	CORRECTING TWEET_ID 666287406224695296 ...
#
# After correction: rating = 9/10

# %% [markdown]
# ### ***Test***

# %%
# overall check
df_join_clean.head(1)
# Out:
#                                    timestamp              source  \
# tweet_id
# 892420643555336193 2017-08-01 16:23:56+00:00  Twitter for iPhone
#
#                                                                                                                              text  \
# tweet_id
# 892420643555336193  This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU
#
#                                                                       expanded_urls  \
# tweet_id
# 892420643555336193  https://twitter.com/dog_rates/status/892420643555336193/photo/1
#
#                     rating_numerator  rating_denominator     name doggo  \
# tweet_id
# 892420643555336193                13                  10  Phineas  None
#
#                    floofer pupper  ... p2_dog      p3  p3_conf p3_dog  \
# tweet_id                           ...
# 892420643555336193    None   None  ...  False  banana  0.07611  False
#
#                     retweet_count  favorite_count rating  num  den  \
# tweet_id
# 892420643555336193           8287           37931  13/10   13   10
#
#                    no_of_ratings_per_tweet
# tweet_id
# 892420643555336193                       1
#
# [1 rows x 28 columns]

# %%
# dropping redundant columns
cols_to_drop = ['rating_numerator', 'rating_denominator', 'rating', 'no_of_ratings_per_tweet']
df_join_clean.drop(columns = cols_to_drop, inplace=True)

# check
df_join_clean.head(1)
# Out:
#                                    timestamp              source  \
# tweet_id
# 892420643555336193 2017-08-01 16:23:56+00:00  Twitter for iPhone
#
#                                                                                                                              text  \
# tweet_id
# 892420643555336193  This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU
#
#                                                                       expanded_urls  \
# tweet_id
# 892420643555336193  https://twitter.com/dog_rates/status/892420643555336193/photo/1
#
#                        name doggo floofer pupper puppo  \
# tweet_id
# 892420643555336193  Phineas  None    None   None  None
#
#                                                             jpg_url  ...  \
# tweet_id                                                             ...
# 892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg  ...
#
#                        p2   p2_conf  p2_dog      p3  p3_conf  p3_dog  \
# tweet_id
# 892420643555336193  bagel  0.085851   False  banana  0.07611   False
#
#                     retweet_count favorite_count  num  den
# tweet_id
# 892420643555336193           8287          37931   13   10
#
# [1 rows x 24 columns]

# %%
# renaming num and den with their old names
renamed ={
    'num': 'rating_numerator',
    'den': 'rating_denominator'
}
df_join_clean.rename(columns=renamed, inplace=True)

# check
df_join_clean.columns
# Out:
# Index(['timestamp', 'source', 'text', 'expanded_urls', 'name', 'doggo',
#        'floofer', 'pupper', 'puppo', 'jpg_url', 'img_num', 'p1', 'p1_conf',
#        'p1_dog', 'p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog',
#        'retweet_count', 'favorite_count', 'rating_numerator',
#        'rating_denominator'],
#       dtype='object')

# %% [markdown]
# ### ***Issue 6***: *Dealing with numerator and denominator ratings datatype*
# `df_join_clean`: The regex extracted strings
#
# ### ***Define***<br>
# Convert to float using .astype method

# %% [markdown]
# ### ***Code***

# %%
# converting rating_numerator and rating_denominator to float datatype
df_join_clean['rating_numerator'] = df_join_clean['rating_numerator'].astype('float')
df_join_clean['rating_denominator'] = df_join_clean['rating_denominator'].astype('float')

# %% [markdown]
# ### ***Test***

# %%
df_join_clean.dtypes
# Out:
# timestamp             datetime64[ns, UTC]
# source                             object
# text                               object
# expanded_urls                      object
# name                               object
# doggo                              object
# floofer                            object
# pupper                             object
# puppo                              object
# jpg_url                            object
# img_num                             int64
# p1                                 object
# p1_conf                           float64
# p1_dog                               bool
# p2                                 object
# p2_conf                           float64
# p2_dog                               bool
# p3                                 object
# p3_conf                           float64
# p3_dog                               bool
# retweet_count                       int64
# favorite_count                      int64
# rating_numerator                  float64
# rating_denominator                float64
# dtype: object

# %% [markdown]
# ### ***Issue 7***: *tweets with invalid names*
# `df_join_clean`: The name column contain some invalid names
#
# ### ***Define***<br>
#  - Identify culprit rows by filtering for names with low character counts
#  - Input correct names if name actually exist in the text column
#  - If no name exists impute generic name `Nameless`

# %% [markdown]
# ### ***Code***

# %%
# getting the names with length less = 1 
mask = df_join_clean['name'].apply(lambda x: len(x) == 1)
df_join_clean[['text', 'name', 'p1']][mask]
# Out:
#                                                                                                                                                                            text  \
# tweet_id
# 881536004380872706  Here is a pupper approaching maximum borkdrive. Zooming at never before seen speeds. 14/10 paw-inspiring af \n(IG: puffie_the_chow) https://t.co/ghXBIIeQZF
# 792913359805018113                             Here is a perfect example of someone who has their priorities in order. 13/10 for both owner and Forrest https://t.co/LRyMrU7Wfq
# 776201521193218049                                        This is O'Malley. That is how he sleeps. Doesn't care what you think about it. 10/10 comfy af https://t.co/Pq150LeRaC
# 772581559778025472                 Guys this is getting so out of hand. We only rate dogs. This is a Galapagos Speed Panda. Pls only send dogs... 10/10 https://t.co/8lpAGaZRFn
# 747885874273214464                 This is a mighty rare blue-tailed hammer sherk. Human almost lost a limb trying to take these. Be careful guys. 8/10 https://t.co/TGenMeXreW
# 747816857231626240                   Viewer discretion is advised. This is a terrible attack in progress. Not even in water (tragic af). 4/10 bad sherk https://t.co/L3U0j14N5R
# 746872823977771008                       This is a carrot. We only rate dogs. Please only send in dogs. You all really should know this by now ...11/10 https://t.co/9e48aPrBm2
# 743222593470234624                   This is a very rare Great Alaskan Bush Pupper. Hard to stumble upon without spooking. 12/10 would pet passionately https://t.co/xOBKCdpzaa
# 717537687239008257                  People please. This is a Deadly Mediterranean Plop T-Rex. We only rate dogs. Only send in dogs. Thanks you... 11/10 https://t.co/2ATDsgHD4n
# 715733265223708672                    This is a taco. We only rate dogs. Please only send in dogs. Dogs are what we rate. Not tacos. Thank you... 10/10 https://t.co/cxl6xGY8B9
# 704859558691414016                                           Here is a heartbreaking scene of an incredible pupper being laid to rest. 10/10 RIP pupper https://t.co/81mvJ0rGRu
# 704054845121142784                                                                           Here is a whole flock of puppers.  60/50 I'll take the lot https://t.co/9dpcw6MdWa
# 703079050210877440                  This is a Butternut Cumberfloof. It's not windy they just look like that. 11/10 back at it again with the red socks https://t.co/hMjzhdUHaW
# 702539513671897089                     This is a Wild Tuscan Poofwiggle. Careful not to startle. Rare tongue slip. One eye magical. 12/10 would def pet https://t.co/4EnShAQjv6
# 700864154249383937                                                     "Pupper is a present to world. Here is a bow for pupper." 12/10 precious as hell https://t.co/ItSsE92gCW
# 692187005137076224                  This is a rare Arctic Wubberfloof. Unamused by the happenings. No longer has the appetites. 12/10 would totally hug https://t.co/krvbacIX0N
# 679530280114372609                 Guys this really needs to stop. We've been over this way too many times. This is a giraffe. We only rate dogs.. 7/10 https://t.co/yavgkHYPOC
# 677644091929329666                                                      This is a dog swinging. I really enjoyed it so I hope you all do as well. 11/10 https://t.co/Ozo9KHTRND
# 675706639471788032                 This is a Sizzlin Menorah spaniel from Brooklyn named Wylie. Lovable eyes. Chiller as hell. 10/10 and I'm out.. poof https://t.co/7E0AiJXPmI
# 675534494439489536                                             Seriously guys?! Only send in dogs. I only rate dogs. This is a baby black bear... 11/10 https://t.co/H7kpabTfLj
# 675109292475830276                    C'mon guys. We've been over this. We only rate dogs. This is a cow. Please only submit dogs. Thank you...... 9/10 https://t.co/WjcELNEqN2
# 675047298674663426                                        This is a fluffy albino Bacardi Columbia mix. Excellent at the tweets. 11/10 would hug gently https://t.co/diboDRUuEI
# 674082852460433408                                                               This is a Sagitariot Baklava mix. Loves her new hat. 11/10 radiant pup https://t.co/Bko5kFJYUU
# 673715861853720576                       This is a heavily opinionated dog. Loves walls. Nobody knows how the hair works. Always ready for a kiss. 4/10 https://t.co/dFiaKZ9cDl
# 673636718965334016                  This is a Lofted Aphrodisiac Terrier named Kip. Big fan of bed n breakfasts. Fits perfectly. 10/10 would pet firmly https://t.co/gKlLpNzIl3
# 672604026190569472                                                         This is a baby Rand Paul. Curls for days. 11/10 would cuddle the hell out of https://t.co/xHXNaPAYRe
# 671743150407421952                     This is a Tuscaloosa Alcatraz named Jacob (Yacōb). Loves to sit in swing. Stellar tongue. 11/10 look at his feet https://t.co/2IslQ8ZSc7
# 671147085991960577                 This is a Helvetica Listerine named Rufus. This time Rufus will be ready for the UPS guy. He'll never expect it 9/10 https://t.co/34OhVhMkVr
# 670427002554466305                  This is a Deciduous Trimester mix named Spork. Only 1 ear works. No seat belt. Incredibly reckless. 9/10 still cute https://t.co/CtuJoLHiDo
# 670361874861563904                    This is a Rich Mahogany Seltzer named Cherokee. Just got destroyed by a snowball. Isn't very happy about it. 9/10 https://t.co/98ZBi6o4dj
# 670303360680108032                   This is a Speckled Cauliflower Yosemite named Hemry. He's terrified of intruder dog. Not one bit comfortable. 9/10 https://t.co/yV3Qgjh8iN
# 669923323644657664                   This is a spotted Lipitor Rumpelstiltskin named Alphred. He can't wait for the Turkey. 10/10 would pet really well https://t.co/6GUGO7azNX
# 669661792646373376                  This is a brave dog. Excellent free climber. Trying to get closer to God. Not very loyal though. Doesn't bark. 5/10 https://t.co/ODnILTr4QM
# 669564461267722241                   This is a Coriander Baton Rouge named Alfredo. Loves to cuddle with smaller well-dressed dog. 10/10 would hug lots https://t.co/eCRdwouKCl
# 668955713004314625                 This is a Slovakian Helter Skelter Feta named Leroi. Likes to skip on roofs. Good traction. Much balance. 10/10 wow! https://t.co/Dmy2mY2Qj5
# 668815180734689280                    This is a wild Toblerone from Papua New Guinea. Mouth always open. Addicted to hay. Acts blind. 7/10 handsome dog https://t.co/IGmVbz07tZ
# 668614819948453888                  Here is a horned dog. Much grace. Can jump over moons (dam!). Paws not soft. Bad at barking. 7/10 can still pet tho https://t.co/2Su7gmsnZm
# 668507509523615744                   This is a Birmingham Quagmire named Chuk. Loves to relax and watch the game while sippin on that iced mocha. 10/10 https://t.co/HvNg9JWxFt
# 668466899341221888                      Here is a mother dog caring for her pups. Snazzy red mohawk. Doesn't wag tail. Pups look confused. Overall 4/10 https://t.co/YOHe6lf09m
# 668171859951755264                            This is a Trans Siberian Kellogg named Alfonso. Huge ass eyeballs. Actually Dobby from Harry Potter. 7/10 https://t.co/XpseHBlAAb
# 667861340749471744                 This is a Shotokon Macadamia mix named Cheryl. Sophisticated af. Looks like a disappointed librarian. Shh (lol) 9/10 https://t.co/J4GnJ5Swba
# 667773195014021121                     This is a rare Hungarian Pinot named Jessiga. She is either mid-stroke or got stuck in the washing machine. 8/10 https://t.co/ZU0i0KJyqD
# 667538891197542400                                       This is a southwest Coriander named Klint. Hat looks expensive. Still on house arrest :(\n9/10 https://t.co/IQTOMqDUIe
# 667470559035432960                   This is a northern Wahoo named Kohl. He runs this town. Chases tumbleweeds. Draws gun wicked fast. 11/10 legendary https://t.co/J4vn2rOYFk
# 667177989038297088                       This is a Dasani Kingfisher from Maine. His name is Daryl. Daryl doesn't like being swallowed by a panda. 8/10 https://t.co/jpaeu6LNmW
# 666983947667116034                                     This is a curly Ticonderoga named Pepe. No feet. Loves to jet ski. 11/10 would hug until forever https://t.co/cyDfaK8NBc
# 666781792255496192                                                  This is a purebred Bacardi named Octaviath. Can shoot spaghetti out of mouth. 10/10 https://t.co/uEvsGLOFHa
# 666701168228331520                  This is a golden Buckminsterfullerene named Johm. Drives trucks. Lumberjack (?). Enjoys wall. 8/10 would hug softly https://t.co/uQbZJM2DQB
# 666407126856765440                  This is a southern Vesuvius bumblegruff. Can drive a truck (wow). Made friends with 5 other nifty dogs (neat). 7/10 https://t.co/LopTBkKa8h
# 666293911632134144                   This is a funny dog. Weird toes. Won't come down. Loves branch. Refuses to eat his food. Hard to cuddle with. 3/10 https://t.co/IIXis0zta0
# 666057090499244032                                 My oh my. This is a rare blond Canadian terrier on wheels. Only $8.98. Rather docile. 9/10 very rare https://t.co/yWBqbrzy8O
# 666055525042405380                 Here is a Siberian heavily armored polar bear mix. Strong owner. 10/10 I would do unspeakable things to pet this dog https://t.co/rdivxLiqEt
# 666050758794694657                 This is a truly beautiful English Wilson Staff retriever. Has a nice phone. Privileged. 10/10 would trade lives with https://t.co/fvIbQfHjIe
# 666044226329800704                    This is a purebred Piers Morgan. Loves to Netflix and chill. Always looks like he forgot to unplug the iron. 6/10 https://t.co/DWnyCjf2mx
# 666033412701032449                           Here is a very happy pup. Big fan of well-maintained decks. Just look at that tongue. 9/10 would cuddle af https://t.co/y671yMhoiR
# 666029285002620928                  This is a western brown Mitsubishi terrier. Upset about leaf. Actually 2 dogs here. 7/10 would walk the shit out of https://t.co/r7mOb2m0UI
#
#                    name                           p1
# tweet_id
# 881536004380872706    a                      Samoyed
# 792913359805018113    a                     web_site
# 776201521193218049    O                   Rottweiler
# 772581559778025472    a                 Newfoundland
# 747885874273214464    a                       kuvasz
# 747816857231626240    a                     Pembroke
# 746872823977771008    a                     Pembroke
# 743222593470234624    a                       kuvasz
# 717537687239008257    a             golden_retriever
# 715733265223708672    a               Dandie_Dinmont
# 704859558691414016    a                          pug
# 704054845121142784    a               Great_Pyrenees
# 703079050210877440    a                     Pembroke
# 702539513671897089    a                   Pomeranian
# 700864154249383937    a                       kuvasz
# 692187005137076224    a               Siberian_husky
# 679530280114372609    a                    dalmatian
# 677644091929329666    a                    Chihuahua
# 675706639471788032    a             English_springer
# 675534494439489536    a                         chow
# 675109292475830276    a                    dalmatian
# 675047298674663426    a                      Samoyed
# 674082852460433408    a                   Pomeranian
# 673715861853720576    a                         suit
# 673636718965334016    a                       wombat
# 672604026190569472    a                   toy_poodle
# 671743150407421952    a                   toy_poodle
# 671147085991960577    a            Yorkshire_terrier
# 670427002554466305    a                    seat_belt
# 670361874861563904    a                     platypus
# 670303360680108032    a            Shetland_sheepdog
# 669923323644657664    a                   car_mirror
# 669661792646373376    a                       weasel
# 669564461267722241    a                   toy_poodle
# 668955713004314625    a               cocker_spaniel
# 668815180734689280    a                      redbone
# 668614819948453888    a                      bustard
# 668507509523615744    a                      basenji
# 668466899341221888    a              shopping_basket
# 668171859951755264    a                    Chihuahua
# 667861340749471744    a                     malamute
# 667773195014021121    a  West_Highland_white_terrier
# 667538891197542400    a            Yorkshire_terrier
# 667470559035432960    a                   toy_poodle
# 667177989038297088    a                       vizsla
# 666983947667116034    a                         swab
# 666781792255496192    a            Italian_greyhound
# 666701168228331520    a           Labrador_retriever
# 666407126856765440    a      black-and-tan_coonhound
# 666293911632134144    a             three-toed_sloth
# 666057090499244032    a                shopping_cart
# 666055525042405380    a                         chow
# 666050758794694657    a         Bernese_mountain_dog
# 666044226329800704    a          Rhodesian_ridgeback
# 666033412701032449    a              German_shepherd
# 666029285002620928    a                      redbone

# %%
# putting these indexes into a list
bad_names_index = df_join_clean[['text', 'name', 'p1']][mask].index.to_list()
bad_names_index
# Out:
# [881536004380872706,
#  792913359805018113,
#  776201521193218049,
#  772581559778025472,
#  747885874273214464,
#  747816857231626240,
#  746872823977771008,
#  743222593470234624,
#  717537687239008257,
#  715733265223708672,
#  704859558691414016,
#  704054845121142784,
#  703079050210877440,
#  702539513671897089,
#  700864154249383937,
#  692187005137076224,
#  679530280114372609,
#  677644091929329666,
#  675706639471788032,
#  675534494439489536,
#  675109292475830276,
#  675047298674663426,
#  674082852460433408,
#  673715861853720576,
#  673636718965334016,
#  672604026190569472,
#  671743150407421952,
#  671147085991960577,
#  670427002554466305,
#  670361874861563904,
#  670303360680108032,
#  669923323644657664,
#  669661792646373376,
#  669564461267722241,
#  668955713004314625,
#  668815180734689280,
#  668614819948453888,
#  668507509523615744,
#  668466899341221888,
#  668171859951755264,
#  667861340749471744,
#  667773195014021121,
#  667538891197542400,
#  667470559035432960,
#  667177989038297088,
#  666983947667116034,
#  666781792255496192,
#  666701168228331520,
#  666407126856765440,
#  666293911632134144,
#  666057090499244032,
#  666055525042405380,
#  666050758794694657,
#  666044226329800704,
#  666033412701032449,
#  666029285002620928]

# %%
# getting count of these rows
len(bad_names_index)
# Out:
# 56

# %% [markdown]
# *I use a while loop to check each row if the text column actually contains a name*

# %%
# initializing variable count 
count = 0

# %%
# executing the loop
while True:
    row = df_join_clean.loc[bad_names_index[count]][['text', 'name', 'p1']]
    count += 1
    print(row) 
    break
# Out:
# text    Here is a pupper approaching maximum borkdrive. Zooming at never before seen speeds. 14/10 paw-inspiring af \n(IG: puffie_the_chow) https://t.co/ghXBIIeQZF
# name                                                                                                                                                              a
# p1                                                                                                                                                          Samoyed
# Name: 881536004380872706, dtype: object

# %% [markdown]
# **I manually extracted the following names from their tweet's text after checking the loop's output, iteratively**
#
# 792913359805018113 = Forrest   <br>
# 776201521193218049 = O'Malley<br>
# 675706639471788032 = Wylie<br>
# 673636718965334016 = Kip<br>
# 671743150407421952 = Jacob<br>
# 671147085991960577 = Rufus<br>
# 670427002554466305 = Spork<br>
# 670361874861563904 = Cherokee<br>
# 670303360680108032 = Hemry<br>
# 669923323644657664 = Alphred<br>
# 669564461267722241 = Alfredo<br>
# 668955713004314625 = Leroi<br>
# 668507509523615744 = Chuk<br>
# 667861340749471744 = Cheryl<br>
# 668171859951755264 = Alfonso<br>
# 667773195014021121 = Jessiga<br>
# 667538891197542400 = Klint<br>
# 667470559035432960 = Kohl<br>
# 667177989038297088 = Daryl<br>
# 666983947667116034 = Pepe<br>
# 666781792255496192 = Octaviath<br>
# 666701168228331520 = Johm<br>

# %%
# putting into a dictionary
dict = {
"792913359805018113" : "Forrest",
"776201521193218049" : "O'Malley",
"675706639471788032" : "Wylie",
"673636718965334016" : "Kip",
"671743150407421952" : "Jacob",
"671147085991960577" : "Rufus",
"670427002554466305" : "Spork",
"670361874861563904" : "Cherokee",
"670303360680108032" : "Hemry",
"669923323644657664" : "Alphred",
"669564461267722241" : "Alfredo",
"668955713004314625" : "Leroi",
"668507509523615744" : "Chuk",
"668171859951755264" : "Alfonso",
"667861340749471744" : "Cheryl",
"667773195014021121" : "Jessiga",
"667538891197542400" : "Klint",
"667470559035432960" : "Kohl",
"667177989038297088" : "Daryl",
"666983947667116034" : "Pepe",
"666781792255496192" : "Octaviath",
"666701168228331520" : "Johm"
}

# %%
# looping through the dictionary and inputing the names
for key, value in dict.items():
  
    df_join_clean.loc[int(key), 'name'] = value

# %% [markdown]
# ### ***Test***

# %%
# getting the names with length = 1 
mask = df_join_clean['name'].apply(lambda x: len(x) == 1)
df_join_clean[['text', 'name', 'p1']][mask]
# Out:
#                                                                                                                                                                            text  \
# tweet_id
# 881536004380872706  Here is a pupper approaching maximum borkdrive. Zooming at never before seen speeds. 14/10 paw-inspiring af \n(IG: puffie_the_chow) https://t.co/ghXBIIeQZF
# 772581559778025472                 Guys this is getting so out of hand. We only rate dogs. This is a Galapagos Speed Panda. Pls only send dogs... 10/10 https://t.co/8lpAGaZRFn
# 747885874273214464                 This is a mighty rare blue-tailed hammer sherk. Human almost lost a limb trying to take these. Be careful guys. 8/10 https://t.co/TGenMeXreW
# 747816857231626240                   Viewer discretion is advised. This is a terrible attack in progress. Not even in water (tragic af). 4/10 bad sherk https://t.co/L3U0j14N5R
# 746872823977771008                       This is a carrot. We only rate dogs. Please only send in dogs. You all really should know this by now ...11/10 https://t.co/9e48aPrBm2
# 743222593470234624                   This is a very rare Great Alaskan Bush Pupper. Hard to stumble upon without spooking. 12/10 would pet passionately https://t.co/xOBKCdpzaa
# 717537687239008257                  People please. This is a Deadly Mediterranean Plop T-Rex. We only rate dogs. Only send in dogs. Thanks you... 11/10 https://t.co/2ATDsgHD4n
# 715733265223708672                    This is a taco. We only rate dogs. Please only send in dogs. Dogs are what we rate. Not tacos. Thank you... 10/10 https://t.co/cxl6xGY8B9
# 704859558691414016                                           Here is a heartbreaking scene of an incredible pupper being laid to rest. 10/10 RIP pupper https://t.co/81mvJ0rGRu
# 704054845121142784                                                                           Here is a whole flock of puppers.  60/50 I'll take the lot https://t.co/9dpcw6MdWa
# 703079050210877440                  This is a Butternut Cumberfloof. It's not windy they just look like that. 11/10 back at it again with the red socks https://t.co/hMjzhdUHaW
# 702539513671897089                     This is a Wild Tuscan Poofwiggle. Careful not to startle. Rare tongue slip. One eye magical. 12/10 would def pet https://t.co/4EnShAQjv6
# 700864154249383937                                                     "Pupper is a present to world. Here is a bow for pupper." 12/10 precious as hell https://t.co/ItSsE92gCW
# 692187005137076224                  This is a rare Arctic Wubberfloof. Unamused by the happenings. No longer has the appetites. 12/10 would totally hug https://t.co/krvbacIX0N
# 679530280114372609                 Guys this really needs to stop. We've been over this way too many times. This is a giraffe. We only rate dogs.. 7/10 https://t.co/yavgkHYPOC
# 677644091929329666                                                      This is a dog swinging. I really enjoyed it so I hope you all do as well. 11/10 https://t.co/Ozo9KHTRND
# 675534494439489536                                             Seriously guys?! Only send in dogs. I only rate dogs. This is a baby black bear... 11/10 https://t.co/H7kpabTfLj
# 675109292475830276                    C'mon guys. We've been over this. We only rate dogs. This is a cow. Please only submit dogs. Thank you...... 9/10 https://t.co/WjcELNEqN2
# 675047298674663426                                        This is a fluffy albino Bacardi Columbia mix. Excellent at the tweets. 11/10 would hug gently https://t.co/diboDRUuEI
# 674082852460433408                                                               This is a Sagitariot Baklava mix. Loves her new hat. 11/10 radiant pup https://t.co/Bko5kFJYUU
# 673715861853720576                       This is a heavily opinionated dog. Loves walls. Nobody knows how the hair works. Always ready for a kiss. 4/10 https://t.co/dFiaKZ9cDl
# 672604026190569472                                                         This is a baby Rand Paul. Curls for days. 11/10 would cuddle the hell out of https://t.co/xHXNaPAYRe
# 669661792646373376                  This is a brave dog. Excellent free climber. Trying to get closer to God. Not very loyal though. Doesn't bark. 5/10 https://t.co/ODnILTr4QM
# 668815180734689280                    This is a wild Toblerone from Papua New Guinea. Mouth always open. Addicted to hay. Acts blind. 7/10 handsome dog https://t.co/IGmVbz07tZ
# 668614819948453888                  Here is a horned dog. Much grace. Can jump over moons (dam!). Paws not soft. Bad at barking. 7/10 can still pet tho https://t.co/2Su7gmsnZm
# 668466899341221888                      Here is a mother dog caring for her pups. Snazzy red mohawk. Doesn't wag tail. Pups look confused. Overall 4/10 https://t.co/YOHe6lf09m
# 666407126856765440                  This is a southern Vesuvius bumblegruff. Can drive a truck (wow). Made friends with 5 other nifty dogs (neat). 7/10 https://t.co/LopTBkKa8h
# 666293911632134144                   This is a funny dog. Weird toes. Won't come down. Loves branch. Refuses to eat his food. Hard to cuddle with. 3/10 https://t.co/IIXis0zta0
# 666057090499244032                                 My oh my. This is a rare blond Canadian terrier on wheels. Only $8.98. Rather docile. 9/10 very rare https://t.co/yWBqbrzy8O
# 666055525042405380                 Here is a Siberian heavily armored polar bear mix. Strong owner. 10/10 I would do unspeakable things to pet this dog https://t.co/rdivxLiqEt
# 666050758794694657                 This is a truly beautiful English Wilson Staff retriever. Has a nice phone. Privileged. 10/10 would trade lives with https://t.co/fvIbQfHjIe
# 666044226329800704                    This is a purebred Piers Morgan. Loves to Netflix and chill. Always looks like he forgot to unplug the iron. 6/10 https://t.co/DWnyCjf2mx
# 666033412701032449                           Here is a very happy pup. Big fan of well-maintained decks. Just look at that tongue. 9/10 would cuddle af https://t.co/y671yMhoiR
# 666029285002620928                  This is a western brown Mitsubishi terrier. Upset about leaf. Actually 2 dogs here. 7/10 would walk the shit out of https://t.co/r7mOb2m0UI
#
#                    name                       p1
# tweet_id
# 881536004380872706    a                  Samoyed
# 772581559778025472    a             Newfoundland
# 747885874273214464    a                   kuvasz
# 747816857231626240    a                 Pembroke
# 746872823977771008    a                 Pembroke
# 743222593470234624    a                   kuvasz
# 717537687239008257    a         golden_retriever
# 715733265223708672    a           Dandie_Dinmont
# 704859558691414016    a                      pug
# 704054845121142784    a           Great_Pyrenees
# 703079050210877440    a                 Pembroke
# 702539513671897089    a               Pomeranian
# 700864154249383937    a                   kuvasz
# 692187005137076224    a           Siberian_husky
# 679530280114372609    a                dalmatian
# 677644091929329666    a                Chihuahua
# 675534494439489536    a                     chow
# 675109292475830276    a                dalmatian
# 675047298674663426    a                  Samoyed
# 674082852460433408    a               Pomeranian
# 673715861853720576    a                     suit
# 672604026190569472    a               toy_poodle
# 669661792646373376    a                   weasel
# 668815180734689280    a                  redbone
# 668614819948453888    a                  bustard
# 668466899341221888    a          shopping_basket
# 666407126856765440    a  black-and-tan_coonhound
# 666293911632134144    a         three-toed_sloth
# 666057090499244032    a            shopping_cart
# 666055525042405380    a                     chow
# 666050758794694657    a     Bernese_mountain_dog
# 666044226329800704    a      Rhodesian_ridgeback
# 666033412701032449    a          German_shepherd
# 666029285002620928    a                  redbone

# %%
# note the reduction in row count. Earlier when I ran this code, it was 56
len(df_join_clean[['text', 'name', 'p1']][mask])
# Out:
# 34

# %% [markdown]
#  ### ***Define***<br>
#  - For dogs (or non-dog items) with no names, input with a catch-all name, `Nameless`

# %% [markdown]
# ### ***Code***

# %%
# getting the names with length = 1 
mask = df_join_clean['name'].apply(lambda x: len(x) == 1)
df_join_clean[['text', 'name', 'p1']][mask]
# Out:
#                                                                                                                                                                            text  \
# tweet_id
# 881536004380872706  Here is a pupper approaching maximum borkdrive. Zooming at never before seen speeds. 14/10 paw-inspiring af \n(IG: puffie_the_chow) https://t.co/ghXBIIeQZF
# 772581559778025472                 Guys this is getting so out of hand. We only rate dogs. This is a Galapagos Speed Panda. Pls only send dogs... 10/10 https://t.co/8lpAGaZRFn
# 747885874273214464                 This is a mighty rare blue-tailed hammer sherk. Human almost lost a limb trying to take these. Be careful guys. 8/10 https://t.co/TGenMeXreW
# 747816857231626240                   Viewer discretion is advised. This is a terrible attack in progress. Not even in water (tragic af). 4/10 bad sherk https://t.co/L3U0j14N5R
# 746872823977771008                       This is a carrot. We only rate dogs. Please only send in dogs. You all really should know this by now ...11/10 https://t.co/9e48aPrBm2
# 743222593470234624                   This is a very rare Great Alaskan Bush Pupper. Hard to stumble upon without spooking. 12/10 would pet passionately https://t.co/xOBKCdpzaa
# 717537687239008257                  People please. This is a Deadly Mediterranean Plop T-Rex. We only rate dogs. Only send in dogs. Thanks you... 11/10 https://t.co/2ATDsgHD4n
# 715733265223708672                    This is a taco. We only rate dogs. Please only send in dogs. Dogs are what we rate. Not tacos. Thank you... 10/10 https://t.co/cxl6xGY8B9
# 704859558691414016                                           Here is a heartbreaking scene of an incredible pupper being laid to rest. 10/10 RIP pupper https://t.co/81mvJ0rGRu
# 704054845121142784                                                                           Here is a whole flock of puppers.  60/50 I'll take the lot https://t.co/9dpcw6MdWa
# 703079050210877440                  This is a Butternut Cumberfloof. It's not windy they just look like that. 11/10 back at it again with the red socks https://t.co/hMjzhdUHaW
# 702539513671897089                     This is a Wild Tuscan Poofwiggle. Careful not to startle. Rare tongue slip. One eye magical. 12/10 would def pet https://t.co/4EnShAQjv6
# 700864154249383937                                                     "Pupper is a present to world. Here is a bow for pupper." 12/10 precious as hell https://t.co/ItSsE92gCW
# 692187005137076224                  This is a rare Arctic Wubberfloof. Unamused by the happenings. No longer has the appetites. 12/10 would totally hug https://t.co/krvbacIX0N
# 679530280114372609                 Guys this really needs to stop. We've been over this way too many times. This is a giraffe. We only rate dogs.. 7/10 https://t.co/yavgkHYPOC
# 677644091929329666                                                      This is a dog swinging. I really enjoyed it so I hope you all do as well. 11/10 https://t.co/Ozo9KHTRND
# 675534494439489536                                             Seriously guys?! Only send in dogs. I only rate dogs. This is a baby black bear... 11/10 https://t.co/H7kpabTfLj
# 675109292475830276                    C'mon guys. We've been over this. We only rate dogs. This is a cow. Please only submit dogs. Thank you...... 9/10 https://t.co/WjcELNEqN2
# 675047298674663426                                        This is a fluffy albino Bacardi Columbia mix. Excellent at the tweets. 11/10 would hug gently https://t.co/diboDRUuEI
# 674082852460433408                                                               This is a Sagitariot Baklava mix. Loves her new hat. 11/10 radiant pup https://t.co/Bko5kFJYUU
# 673715861853720576                       This is a heavily opinionated dog. Loves walls. Nobody knows how the hair works. Always ready for a kiss. 4/10 https://t.co/dFiaKZ9cDl
# 672604026190569472                                                         This is a baby Rand Paul. Curls for days. 11/10 would cuddle the hell out of https://t.co/xHXNaPAYRe
# 669661792646373376                  This is a brave dog. Excellent free climber. Trying to get closer to God. Not very loyal though. Doesn't bark. 5/10 https://t.co/ODnILTr4QM
# 668815180734689280                    This is a wild Toblerone from Papua New Guinea. Mouth always open. Addicted to hay. Acts blind. 7/10 handsome dog https://t.co/IGmVbz07tZ
# 668614819948453888                  Here is a horned dog. Much grace. Can jump over moons (dam!). Paws not soft. Bad at barking. 7/10 can still pet tho https://t.co/2Su7gmsnZm
# 668466899341221888                      Here is a mother dog caring for her pups. Snazzy red mohawk. Doesn't wag tail. Pups look confused. Overall 4/10 https://t.co/YOHe6lf09m
# 666407126856765440                  This is a southern Vesuvius bumblegruff. Can drive a truck (wow). Made friends with 5 other nifty dogs (neat). 7/10 https://t.co/LopTBkKa8h
# 666293911632134144                   This is a funny dog. Weird toes. Won't come down. Loves branch. Refuses to eat his food. Hard to cuddle with. 3/10 https://t.co/IIXis0zta0
# 666057090499244032                                 My oh my. This is a rare blond Canadian terrier on wheels. Only $8.98. Rather docile. 9/10 very rare https://t.co/yWBqbrzy8O
# 666055525042405380                 Here is a Siberian heavily armored polar bear mix. Strong owner. 10/10 I would do unspeakable things to pet this dog https://t.co/rdivxLiqEt
# 666050758794694657                 This is a truly beautiful English Wilson Staff retriever. Has a nice phone. Privileged. 10/10 would trade lives with https://t.co/fvIbQfHjIe
# 666044226329800704                    This is a purebred Piers Morgan. Loves to Netflix and chill. Always looks like he forgot to unplug the iron. 6/10 https://t.co/DWnyCjf2mx
# 666033412701032449                           Here is a very happy pup. Big fan of well-maintained decks. Just look at that tongue. 9/10 would cuddle af https://t.co/y671yMhoiR
# 666029285002620928                  This is a western brown Mitsubishi terrier. Upset about leaf. Actually 2 dogs here. 7/10 would walk the shit out of https://t.co/r7mOb2m0UI
#
#                    name                       p1
# tweet_id
# 881536004380872706    a                  Samoyed
# 772581559778025472    a             Newfoundland
# 747885874273214464    a                   kuvasz
# 747816857231626240    a                 Pembroke
# 746872823977771008    a                 Pembroke
# 743222593470234624    a                   kuvasz
# 717537687239008257    a         golden_retriever
# 715733265223708672    a           Dandie_Dinmont
# 704859558691414016    a                      pug
# 704054845121142784    a           Great_Pyrenees
# 703079050210877440    a                 Pembroke
# 702539513671897089    a               Pomeranian
# 700864154249383937    a                   kuvasz
# 692187005137076224    a           Siberian_husky
# 679530280114372609    a                dalmatian
# 677644091929329666    a                Chihuahua
# 675534494439489536    a                     chow
# 675109292475830276    a                dalmatian
# 675047298674663426    a                  Samoyed
# 674082852460433408    a               Pomeranian
# 673715861853720576    a                     suit
# 672604026190569472    a               toy_poodle
# 669661792646373376    a                   weasel
# 668815180734689280    a                  redbone
# 668614819948453888    a                  bustard
# 668466899341221888    a          shopping_basket
# 666407126856765440    a  black-and-tan_coonhound
# 666293911632134144    a         three-toed_sloth
# 666057090499244032    a            shopping_cart
# 666055525042405380    a                     chow
# 666050758794694657    a     Bernese_mountain_dog
# 666044226329800704    a      Rhodesian_ridgeback
# 666033412701032449    a          German_shepherd
# 666029285002620928    a                  redbone

# %%
# getting their indexes
nameless_tweets = df_join_clean[['text', 'name', 'p1']][mask].index.to_list()
nameless_tweets
# Out:
# [881536004380872706,
#  772581559778025472,
#  747885874273214464,
#  747816857231626240,
#  746872823977771008,
#  743222593470234624,
#  717537687239008257,
#  715733265223708672,
#  704859558691414016,
#  704054845121142784,
#  703079050210877440,
#  702539513671897089,
#  700864154249383937,
#  692187005137076224,
#  679530280114372609,
#  677644091929329666,
#  675534494439489536,
#  675109292475830276,
#  675047298674663426,
#  674082852460433408,
#  673715861853720576,
#  672604026190569472,
#  669661792646373376,
#  668815180734689280,
#  668614819948453888,
#  668466899341221888,
#  666407126856765440,
#  666293911632134144,
#  666057090499244032,
#  666055525042405380,
#  666050758794694657,
#  666044226329800704,
#  666033412701032449,
#  666029285002620928]

# %%
# writing loop to input 'Nameless' into the name column for each index in nameless_tweets
for name in nameless_tweets:
    df_join_clean.loc[int(name), 'name'] = 'Nameless'

# %% [markdown]
# ### ***Test***

# %%
# getting the names with length = 1 
mask = df_join_clean['name'].apply(lambda x: len(x) == 1)
df_join_clean[['text', 'name', 'p1']][mask]
# Out:
# Empty DataFrame
# Columns: [text, name, p1]
# Index: []

# %%
# using the .sort_values method and .sample method multiple times, I was able to
# identify some invalid names.
df_join_clean['name'].sample(50)
# Out:
# tweet_id
# 805932879469572096       Major
# 743222593470234624    Nameless
# 756288534030475264        None
# 678255464182861824    Jessifer
# 749417653287129088        Finn
# 677918531514703872        None
# 763103485927849985       Belle
# 686683045143953408        Mona
# 870308999962521604      Rumble
# 675489971617296384        None
# 805207613751304193     Shooter
# 689154315265683456        None
# 759793422261743616      Maggie
# 699434518667751424        None
# 881268444196462592      Elliot
# 750041628174217216        Beau
# 813910438903693312      Chubbs
# 888078434458587136      Gerald
# 705975130514706432       Adele
# 788412144018661376      Dexter
# 692919143163629568        None
# 705442520700944385      Cooper
# 674690135443775488     Patrick
# 703769065844768768        None
# 687124485711986689      Samson
# 754120377874386944        None
# 669006782128353280      Tucker
# 790698755171364864       Mosby
# 821149554670182400        Luca
# 812709060537683968      Brandi
# 676089483918516224        None
# 717537687239008257    Nameless
# 670093938074779648       Wally
# 790581949425475584        Duke
# 670833812859932673        Jett
# 857393404942143489        None
# 690400367696297985        Eriq
# 704847917308362754        None
# 681981167097122816     Jimothy
# 684880619965411328        None
# 670704688707301377       Danny
# 778027034220126208      Sophie
# 751205363882532864        None
# 782969140009107456        Cali
# 707420581654872064      Keurig
# 802239329049477120        Loki
# 882762694511734784         Gus
# 675710890956750848       Lenny
# 682429480204398592        None
# 809448704142938112        None
# Name: name, dtype: object

# %% [markdown]
# *Here are the names I found:*<br>
# *[unacceptable, very, this, the, such, space, quite, one, actually, an, getting, his, incredibly, infuriating,*
# *just, light, all, my, not, officially, None, by]*

# %%
not_names = ['unacceptable', 'very', 'this', 'the', 'such', 'space', 'quite', 'one', 'actually', 'an', 'getting', 'his', 'incredibly', 'infuriating',
'just', 'light', 'all', 'my', 'not', 'officially', 'None', 'by']

# %%
# writing a loop to print the texts that these words appear in to check for names
ra = []
for word in not_names:
    
    mask = df_join_clean['name'] == word
    ba = df_join_clean[['text', 'name', 'p1']][mask]
    ra.append(ba)

df_not_names = pd.concat(ra)
df_not_names.head()
# Out:
#                                                                                                                                                             text  \
# tweet_id
# 730924654643314689  We only rate dogs. Pls stop sending non-canines like this Bulgarian Eyeless Porch Bear. This is unacceptable... 9/10 https://t.co/2yctWAUZ3Z
# 770655142660169732   We only rate dogs. Pls stop sending in non-canines like this Arctic Floof Kangaroo. This is very frustrating. 11/10 https://t.co/qlUDuPoE3d
# 745422732645535745  We only rate dogs. Pls stop sending in non-canines like this Jamaican Flop Seal. This is very very frustrating. 9/10 https://t.co/nc53zEN0hZ
# 736225175608430592  We only rate dogs. Please stop sending in non-canines like this Alaskan Flop Turtle. This is very frustrating. 10/10 https://t.co/qXteK6Atxc
# 700747788515020802   We only rate dogs. Pls stop sending in non-canines like this Mongolian grass snake. This is very frustrating. 11/10 https://t.co/22x9SbCYCU
#
#                             name                  p1
# tweet_id
# 730924654643314689  unacceptable             polecat
# 770655142660169732          very      Madagascar_cat
# 745422732645535745          very  Labrador_retriever
# 736225175608430592          very  Labrador_retriever
# 700747788515020802          very      Great_Pyrenees

# %%
# Reviewing the output of the preceding cell, I discovered that
# only for tweet_id 748692773788876800 (Quizno) and 765395769549590528 (Zoey) do I found anything like a valid name

print(df_join_clean.loc[748692773788876800, 'name'])
print(df_join_clean.loc[765395769549590528, 'name'])
# Out:
# his
# my

# %%
# correcting for these rows
df_join_clean.loc[748692773788876800,'name'] = 'Quizno'
df_join_clean.loc[765395769549590528,'name'] = 'Zoey'

# %%
# check
print(df_join_clean.loc[748692773788876800, 'name'])
print(df_join_clean.loc[765395769549590528, 'name'])
# Out:
# Quizno
# Zoey

# %%
# replacing every word in not_names with 'Nameless
df_join_clean['name'].replace(not_names, 'Nameless', inplace=True)

# %% [markdown]
# ### ***Test***

# %%
# check
not_names = ['unacceptable', 'very', 'this', 'the', 'such', 'space', 'quite', 'one', 'actually', 'an', 'getting', 'his', 'incredibly', 'infuriating',
'just', 'light', 'all', 'my', 'not', 'officially', 'None', 'by']

# constructing a dataframe of rows that have their 'text' column containing a word in not_names
ra = []
for word in not_names:
    
    mask = df_join_clean['name'] == word
    ba = df_join_clean[['text', 'name', 'p1']][mask]
    ra.append(ba)

df_not_names = pd.concat(ra)
df_not_names.head()
# Out:
# Empty DataFrame
# Columns: [text, name, p1]
# Index: []

# %%
df_join_clean['name'].sample(50)
# Out:
# tweet_id
# 698703483621523456        Rusty
# 669573570759163904        Linda
# 838561493054533637       Walter
# 755955933503782912     Nameless
# 687664829264453632         Opal
# 772193107915964416       Willem
# 670073503555706880      Winston
# 826958653328592898         Loki
# 680889648562991104       Cheesy
# 789628658055020548          Eli
# 800751577355128832        Mauve
# 730924654643314689     Nameless
# 676089483918516224     Nameless
# 747219827526344708      Atticus
# 728653952833728512      Coleman
# 800388270626521089          Doc
# 698710712454139905      Cuddles
# 720775346191278080     Berkeley
# 865006731092295680        Nelly
# 667171260800061440      Kenneth
# 754449512966619136          Dex
# 670778058496974848     Nameless
# 732726085725589504      Aldrick
# 782969140009107456         Cali
# 859607811541651456     Nameless
# 707693576495472641      Jiminus
# 710269109699739648     Nameless
# 813812741911748608         Gary
# 795076730285391872       Bailey
# 696900204696625153        Rosie
# 819227688460238848         Finn
# 685268753634967552    Hubertson
# 675432746517426176     Nameless
# 668542336805281792     Nameless
# 889880896479866881        Bruno
# 860184849394610176     Nameless
# 666102155909144576     Nameless
# 688547210804498433        Frönq
# 707995814724026368       Farfle
# 738166403467907072         Axel
# 667886921285246976         Erik
# 806542213899489280      Waffles
# 695074328191332352      Lorenzo
# 829011960981237760       Dexter
# 723912936180330496        Sugar
# 805207613751304193      Shooter
# 828372645993398273    Alexander
# 809448704142938112     Nameless
# 672239279297454080       Ridley
# 786233965241827333       Mattie
# Name: name, dtype: object

# %% [markdown]
# ### ***Issue 8***: *variable names as column names*
# `df_join_clean`: The doggo, floofer, pupper and pupper fields should be collapsed into a single field
#
# ### ***Define***<br>
#  - Extract Dogtionary classifications using regex
#  - Drop original columns

# %% [markdown]
# ### ***Code***

# %%
df_join_clean[['text', 'doggo',
       'floofer', 'pupper', 'puppo', 'p1']].sample(5)
# Out:
#                                                                                                                                                             text  \
# tweet_id
# 720059472081784833                  This is Charleson. He lost his plunger. Looked everywhere. Can't find it. So sad. 9/10 would comfort https://t.co/pRHX8yn9Yu
# 753026973505581056  Say hello to Tayzie. She's a Barbadian Bugaboop. Seems quite social. A rare quality for a Bugaboop. 10/10 petable af https://t.co/6qF5YZx6OV
# 680798457301471234        Say hello to Moofasa. He must be a powerful dog. Fenced in for your protection. Just got his ear pierced. 6/10 https://t.co/w6fRfQ3RXD
# 707969809498152960  Meet Rufus. He's a Honeysuckle Firefox. Curly af. Badass tie. About to go on his first date ever 11/10 good luck pup https://t.co/dGoTWNfIsm
# 772581559778025472  Guys this is getting so out of hand. We only rate dogs. This is a Galapagos Speed Panda. Pls only send dogs... 10/10 https://t.co/8lpAGaZRFn
#
#                    doggo floofer pupper puppo                p1
# tweet_id
# 720059472081784833  None    None   None  None  Mexican_hairless
# 753026973505581056  None    None   None  None          Pembroke
# 680798457301471234  None    None   None  None               ram
# 707969809498152960  None    None   None  None        toy_poodle
# 772581559778025472  None    None   None  None      Newfoundland

# %%
# It appears that for these columns, there were no classifications.
# I decide to extract the classifications myself using regex.

df_join_clean["dog_class"] = df_join_clean['text'].str.extract(r'(\bpuppo\b|\bdoggo\b|\bfloofer\b|\bpupper\b)', expand = True)

# %%
# checking
df_join_clean[['text', 'doggo',
       'floofer', 'pupper', 'puppo', 'dog_class', 'p1']].sample(5)
# Out:
#                                                                                                                                                                                       text  \
# tweet_id
# 729463711119904772                                                                                      Meet Pupcasso. You can't afford his art. 13/10 talented af https://t.co/f2VUpy4WO0
# 817415592588222464  Meet Strudel. He's rather h*ckin pupset that your clothes clash. 11/10 click the link to see how u can help Strudel\n\nhttps://t.co/3uxgLz8d0l https://t.co/O0ECL1StB2
# 676582956622721024                            Meet Vinnie. He's having fun while being safe. Well not a lot of fun, but definitely safe, and that's important 8/10 https://t.co/vZYtynZZlH
# 700847567345688576                                  Meet Crouton. He's a Galapagos Boonwiddle. Has a legendary tongue (most Boonwiddles do). Excellent stuff 10/10 https://t.co/110Eeg7KW3
# 787397959788929025                                     This is Moose. He's rather h*ckin dangerous (you can tell by the collar). 11/10 would still attempt to snug https://t.co/lHVHGdDzb3
#
#                    doggo floofer pupper puppo dog_class                   p1
# tweet_id
# 729463711119904772  None    None   None  None       NaN      German_shepherd
# 817415592588222464  None    None   None  None       NaN             Doberman
# 676582956622721024  None    None   None  None       NaN            seat_belt
# 700847567345688576  None    None   None  None       NaN  Rhodesian_ridgeback
# 787397959788929025  None    None   None  None       NaN            Chihuahua

# %%
# checking for value counts of new column
df_join_clean['dog_class'].value_counts(dropna=False)
# Out:
# NaN        1712
# pupper      203
# doggo        66
# puppo        22
# floofer       3
# Name: dog_class, dtype: int64

# %%
# it seems nans occurred where there where no classifications observed. I decide to rename these as 'unclassified' 
df_join_clean['dog_class'].replace(np.nan, 'unclassified', inplace=True)

# %%
# checking
df_join_clean['dog_class'].value_counts(dropna=False)
# Out:
# unclassified    1712
# pupper           203
# doggo             66
# puppo             22
# floofer            3
# Name: dog_class, dtype: int64

# %%
# dropping redundant columns
cols_to_drop = ['doggo', 'floofer', 'pupper', 'puppo']
df_join_clean.drop(columns = cols_to_drop, inplace=True)

# %% [markdown]
# ### ***Test***

# %%
df_join_clean['dog_class'].value_counts()
# Out:
# unclassified    1712
# pupper           203
# doggo             66
# puppo             22
# floofer            3
# Name: dog_class, dtype: int64

# %%
df_join_clean.columns
# Out:
# Index(['timestamp', 'source', 'text', 'expanded_urls', 'name', 'jpg_url',
#        'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2', 'p2_conf', 'p2_dog', 'p3',
#        'p3_conf', 'p3_dog', 'retweet_count', 'favorite_count',
#        'rating_numerator', 'rating_denominator', 'dog_class'],
#       dtype='object')

# %%
df_join_clean['img_num'].sample(5)
# Out:
# tweet_id
# 803638050916102144    1
# 692417313023332352    1
# 675822767435051008    1
# 811744202451197953    1
# 727685679342333952    1
# Name: img_num, dtype: int64

# %% [markdown]
# ### ***Issue 9***: *Collapsing the prediction columns into one variable*
# `df_join_clean`: I decide to summarize the information in `p1','p1_conf','p1_dog','p2', 'p2_conf', 'p2_dog', 'p3','p3_conf', 'p3_dog'`, into<br> a column `predicted_breed`
#
# ### ***Define***<br>
#  - Write a conditional statement to form a single `predicted_breed` depending on 'p1_dog', 'p2_dog', 'p3_dog', taking into account their prediction confidence levels
#
#  - Drop the redundant columns

# %% [markdown]
# ### ***Code***

# %%
# (D.R.Y) Using this function by Christoph Lindstädt [https://github.com/chrislicodes]
# I extracted the dog breed information by checking whether the prediction levels predicts a dog, taking into account their confidence levels 

def get_attr(x):
    """
    INPUT: 
        Columns in this order: Check1, Result1, Check2, Result2, Result3
    OUTPUT:
        Results based on the check in this columns
    """
    if x[0] == True:
        return x[1]
    elif x[2] == True:
        return x[3]
    else:
        return x[4]

# %%
# calling the function
df_join_clean["predicted_breed"] = df_join_clean[["p1_dog", "p1", "p2_dog", "p2", "p3"]].apply(get_attr, axis = 1)
df_join_clean["conf"] = df_join_clean[["p1_dog", "p1_conf", "p2_dog", "p2_conf", "p3_conf"]].apply(get_attr, axis = 1)

# %%
# dropping redundant columns
columns_to_drop = ['p1','p1_conf','p1_dog','p2', 'p2_conf', 'p2_dog', 'p3','p3_conf', 'p3_dog']
df_join_clean.drop(columns=columns_to_drop, inplace=True)

# %% [markdown]
# ### ***Test***

# %%
df_join_clean.columns
# Out:
# Index(['timestamp', 'source', 'text', 'expanded_urls', 'name', 'jpg_url',
#        'img_num', 'retweet_count', 'favorite_count', 'rating_numerator',
#        'rating_denominator', 'dog_class', 'predicted_breed', 'conf'],
#       dtype='object')

# %%
df_join_clean['predicted_breed'].sample(5)
# Out:
# tweet_id
# 705475953783398401    golden_retriever
# 681320187870711809             Samoyed
# 778990705243029504      cocker_spaniel
# 670403879788544000                 pug
# 773704687002451968       silky_terrier
# Name: predicted_breed, dtype: object

# %%
# Removing the underscore and applying title-casing
df_join_clean['predicted_breed'] = df_join_clean['predicted_breed'].str.replace("_"," ").str.title()

# %% [markdown]
# ### ***Test***

# %%
df_join_clean['predicted_breed'].sample(5)
# Out:
# tweet_id
# 695051054296211456                    Boston Bull
# 683481228088049664                       Keeshond
# 829501995190984704                 French Bulldog
# 671542985629241344              Shetland Sheepdog
# 684222868335505415    Soft-Coated Wheaten Terrier
# Name: predicted_breed, dtype: object

# %%
df_join_clean['predicted_breed'].value_counts()
# Out:
# Golden Retriever      158
# Labrador Retriever    108
# Pembroke               95
# Chihuahua              91
# Pug                    63
#                      ...
# Chime                   1
# Cab                     1
# Padlock                 1
# Cup                     1
# Terrapin                1
# Name: predicted_breed, Length: 344, dtype: int64

# %% [markdown]
# ### ***Issue 10***: *Optimizing memory usage*
# `df_join_clean`: I decide to change `source`, `dog_class`, and `predicted_breed` into the category datatype
#
# ### ***Define***<br>
#  - Use the .astype method to convert
#
#  - Check the % reduction

# %%
# checking
df_join_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2006 entries, 892420643555336193 to 666020888022790149
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   timestamp           2006 non-null   datetime64[ns, UTC]
#  1   source              2006 non-null   object
#  2   text                2006 non-null   object
#  3   expanded_urls       2006 non-null   object
#  4   name                2006 non-null   object
#  5   jpg_url             2006 non-null   object
#  6   img_num             2006 non-null   int64
#  7   retweet_count       2006 non-null   int64
#  8   favorite_count      2006 non-null   int64
#  9   rating_numerator    2006 non-null   float64
#  10  rating_denominator  2006 non-null   float64
#  11  dog_class           2006 non-null   object
#  12  predicted_breed     2006 non-null   object
#  13  conf                2006 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(3), int64(3), object(7)
# memory usage: 299.6+ KB

# %%
# checking memory usage
old_mem = df_join_clean.memory_usage(deep=True)
old_mem
# Out:
# Index                  82136
# timestamp              16048
# source                150360
# text                  368077
# expanded_urls         297062
# name                  127164
# jpg_url               211644
# img_num                16048
# retweet_count          16048
# favorite_count         16048
# rating_numerator       16048
# rating_denominator     16048
# dog_class             136565
# predicted_breed       138105
# conf                   16048
# dtype: int64

# %%
# converting datatypes to optimize for memory
df_join_clean['source'] = df_join_clean['source'].astype('category')
df_join_clean['dog_class'] = df_join_clean['dog_class'].astype('category')
df_join_clean['predicted_breed'] = df_join_clean['predicted_breed'].astype('category')

# %% [markdown]
# ### ***Test***

# %%
# checking memory usage again
new_mem = df_join_clean.memory_usage(deep=True)
new_mem
# Out:
# Index                  82136
# timestamp              16048
# source                  2330
# text                  368077
# expanded_urls         297062
# name                  127164
# jpg_url               211644
# img_num                16048
# retweet_count          16048
# favorite_count         16048
# rating_numerator       16048
# rating_denominator     16048
# dog_class               2498
# predicted_breed        35351
# conf                   16048
# dtype: int64

# %%
# check
pct_reduction = round(((old_mem.sum() - new_mem.sum())/old_mem.sum()) * 100, 2)
print(f"Percentage reduction in memory size = {pct_reduction}%")
# Out:
# Percentage reduction in memory size = 23.71%

# %%
df_join_clean.head(1)
# Out:
#                                    timestamp              source  \
# tweet_id
# 892420643555336193 2017-08-01 16:23:56+00:00  Twitter for iPhone
#
#                                                                                                                              text  \
# tweet_id
# 892420643555336193  This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU
#
#                                                                       expanded_urls  \
# tweet_id
# 892420643555336193  https://twitter.com/dog_rates/status/892420643555336193/photo/1
#
#                        name                                          jpg_url  \
# tweet_id
# 892420643555336193  Phineas  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#                     img_num  retweet_count  favorite_count  rating_numerator  \
# tweet_id
# 892420643555336193        1           8287           37931              13.0
#
#                     rating_denominator     dog_class predicted_breed     conf
# tweet_id
# 892420643555336193                10.0  unclassified          Banana  0.07611

# %% [markdown]
# ### For Tidiness, I decide to to split the dataframe into two before storing.
# According to Hadley Wickham... *"Each table should represent one observational unit"*

# %%
df_join_clean
# Out:
#                                    timestamp              source  \
# tweet_id
# 892420643555336193 2017-08-01 16:23:56+00:00  Twitter for iPhone
# 892177421306343426 2017-08-01 00:17:27+00:00  Twitter for iPhone
# 891815181378084864 2017-07-31 00:18:03+00:00  Twitter for iPhone
# 891689557279858688 2017-07-30 15:58:51+00:00  Twitter for iPhone
# 891327558926688256 2017-07-29 16:00:24+00:00  Twitter for iPhone
# ...                                      ...                 ...
# 666049248165822465 2015-11-16 00:24:50+00:00  Twitter for iPhone
# 666044226329800704 2015-11-16 00:04:52+00:00  Twitter for iPhone
# 666033412701032449 2015-11-15 23:21:54+00:00  Twitter for iPhone
# 666029285002620928 2015-11-15 23:05:30+00:00  Twitter for iPhone
# 666020888022790149 2015-11-15 22:32:08+00:00  Twitter for iPhone
#
#                                                                                                                                                                                   text  \
# tweet_id
# 892420643555336193                                                       This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU
# 892177421306343426  This is Tilly. She's just checking pup on you. Hopes you're doing ok. If not, she's available for pats, snugs, boops, the whole bit. 13/10 https://t.co/0Xxu71qeIV
# 891815181378084864                   This is Archie. He is a rare Norwegian Pouncing Corgo. Lives in the tall grass. You never know when one may strike. 12/10 https://t.co/wUnZnhtVJB
# 891689557279858688                                                             This is Darla. She commenced a snooze mid meal. 13/10 happens to the best of us https://t.co/tD36da7qLQ
# 891327558926688256  This is Franklin. He would like you to stop calling him "cute." He is a very fierce shark and should be respected as such. 12/10 #BarkWeek https://t.co/AtUZn91f7f
# ...                                                                                                                                                                                ...
# 666049248165822465                                            Here we have a 1949 1st generation vulpix. Enjoys sweat tea and Fox News. Cannot be phased. 5/10 https://t.co/4B7cOc1EDq
# 666044226329800704                           This is a purebred Piers Morgan. Loves to Netflix and chill. Always looks like he forgot to unplug the iron. 6/10 https://t.co/DWnyCjf2mx
# 666033412701032449                                  Here is a very happy pup. Big fan of well-maintained decks. Just look at that tongue. 9/10 would cuddle af https://t.co/y671yMhoiR
# 666029285002620928                         This is a western brown Mitsubishi terrier. Upset about leaf. Actually 2 dogs here. 7/10 would walk the shit out of https://t.co/r7mOb2m0UI
# 666020888022790149                                 Here we have a Japanese Irish Setter. Lost eye in Vietnam (?). Big fan of relaxing on stair. 8/10 would pet https://t.co/BLDqew2Ijj
#
#                                                                                                                                       expanded_urls  \
# tweet_id
# 892420643555336193                                                                  https://twitter.com/dog_rates/status/892420643555336193/photo/1
# 892177421306343426                                                                  https://twitter.com/dog_rates/status/892177421306343426/photo/1
# 891815181378084864                                                                  https://twitter.com/dog_rates/status/891815181378084864/photo/1
# 891689557279858688                                                                  https://twitter.com/dog_rates/status/891689557279858688/photo/1
# 891327558926688256  https://twitter.com/dog_rates/status/891327558926688256/photo/1,https://twitter.com/dog_rates/status/891327558926688256/photo/1
# ...                                                                                                                                             ...
# 666049248165822465                                                                  https://twitter.com/dog_rates/status/666049248165822465/photo/1
# 666044226329800704                                                                  https://twitter.com/dog_rates/status/666044226329800704/photo/1
# 666033412701032449                                                                  https://twitter.com/dog_rates/status/666033412701032449/photo/1
# 666029285002620928                                                                  https://twitter.com/dog_rates/status/666029285002620928/photo/1
# 666020888022790149                                                                  https://twitter.com/dog_rates/status/666020888022790149/photo/1
#
#                         name                                          jpg_url  \
# tweet_id
# 892420643555336193   Phineas  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
# 892177421306343426     Tilly  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 891815181378084864    Archie  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 891689557279858688     Darla  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 891327558926688256  Franklin  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# ...                      ...                                              ...
# 666049248165822465  Nameless  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 666044226329800704  Nameless  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 666033412701032449  Nameless  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 666029285002620928  Nameless  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 666020888022790149  Nameless  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
#
#                     img_num  retweet_count  favorite_count  rating_numerator  \
# tweet_id
# 892420643555336193        1           8287           37931              13.0
# 892177421306343426        1           6119           32575              13.0
# 891815181378084864        1           4054           24530              12.0
# 891689557279858688        1           8424           41274              13.0
# 891327558926688256        2           9128           39464              12.0
# ...                     ...            ...             ...               ...
# 666049248165822465        1             42             106               5.0
# 666044226329800704        1            137             292               6.0
# 666033412701032449        1             43             123               9.0
# 666029285002620928        1             46             125               7.0
# 666020888022790149        1            498            2530               8.0
#
#                     rating_denominator     dog_class         predicted_breed  \
# tweet_id
# 892420643555336193                10.0  unclassified                  Banana
# 892177421306343426                10.0  unclassified               Chihuahua
# 891815181378084864                10.0  unclassified               Chihuahua
# 891689557279858688                10.0  unclassified      Labrador Retriever
# 891327558926688256                10.0  unclassified                  Basset
# ...                                ...           ...                     ...
# 666049248165822465                10.0  unclassified      Miniature Pinscher
# 666044226329800704                10.0  unclassified     Rhodesian Ridgeback
# 666033412701032449                10.0  unclassified         German Shepherd
# 666029285002620928                10.0  unclassified                 Redbone
# 666020888022790149                10.0  unclassified  Welsh Springer Spaniel
#
#                         conf
# tweet_id
# 892420643555336193  0.076110
# 892177421306343426  0.323581
# 891815181378084864  0.716012
# 891689557279858688  0.168086
# 891327558926688256  0.555712
# ...                      ...
# 666049248165822465  0.560311
# 666044226329800704  0.408143
# 666033412701032449  0.596461
# 666029285002620928  0.506826
# 666020888022790149  0.465074
#
# [2006 rows x 14 columns]

# %%
# displaying the columns
df_join_clean.columns
# Out:
# Index(['timestamp', 'source', 'text', 'expanded_urls', 'name', 'jpg_url',
#        'img_num', 'retweet_count', 'favorite_count', 'rating_numerator',
#        'rating_denominator', 'dog_class', 'predicted_breed', 'conf'],
#       dtype='object')

# %%
# selecting the columns
tweets = ['timestamp', 'source', 'text', 'expanded_urls', 'jpg_url', 'img_num', 'retweet_count', 'favorite_count']
dogs = ['name', 'rating_numerator', 'rating_denominator', 'dog_class', 'predicted_breed', 'conf' ]

# %%
# splitting the dataframe
tweets_df = df_join_clean[tweets]
dogs_df = df_join_clean[dogs]

# %%
tweets_df.shape
# Out:
# (2006, 8)

# %%
dogs_df.shape
# Out:
# (2006, 6)

# %% [markdown]
# <a id='storing'></a>
# # `Storing Data`

# %%
# saving to .csv files as per requirements
df_join_clean.to_csv('twitter_archive_master.csv')
tweets_df.to_csv('tweets_cleaned.csv')
dogs_df.to_csv('dogs_data.csv')

# %% [markdown]
# <a id='analysis'></a>
# # `Analyzing and Visualizing Data`

# %%
df_join_clean.columns
# Out:
# Index(['timestamp', 'source', 'text', 'expanded_urls', 'name', 'jpg_url',
#        'img_num', 'retweet_count', 'favorite_count', 'rating_numerator',
#        'rating_denominator', 'dog_class', 'predicted_breed', 'conf'],
#       dtype='object')

# %% [markdown]
# ## Exploratory Data Analysis
# ### Univariate Plots

# %% [markdown]
# ### `Categorical Data`
# ------

# %%
# selecting categorical columns
df_join_clean.select_dtypes(include=["category"]).columns
# Out:
# Index(['source', 'dog_class', 'predicted_breed'], dtype='object')

# %%
# univariate plot of name
fig, ax = plt.subplots(1, figsize=(20, 7))
g = pd.DataFrame(df_join_clean['name'].value_counts().head(20)).reset_index()
sns.barplot(data=g, x='index', y='name', palette='viridis')
plt.title('Distribution of The 20 Most Occuring Dog Names', fontdict={'fontsize': 16, 'fontweight':'bold'})
plt.xlabel('Dog Names', fontweight= 'bold') 
plt.ylabel('Frequency', fontweight= 'bold')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df_join_clean[['name']].describe().T
# Out:
#      count unique       top freq
# name  2006    933  Nameless  635

# %% [markdown]
# > Most of the dogs featured in the tweets do not have names. Consequently, I will exclude this category

# %%
# univariate plot of name (excluding 'nameless' category)
fig, ax = plt.subplots(1, figsize=(20, 7))
g = pd.DataFrame(df_join_clean['name'].value_counts().head(20)).reset_index()[1:]
sns.barplot(data=g, x='index', y='name', palette='viridis')
plt.title('Distribution of The 19 Most Occuring Dog Names (excluding dogs without names)', fontdict={'fontsize': 16, 'fontweight':'bold'})
plt.xlabel('Dog Names', fontweight= 'bold') 
plt.ylabel('Frequency', fontweight= 'bold')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# > Lucy, Oliver, Charlie and Cooper are quite popular dog names

# %%
# univariate plot of source
fig, ax = plt.subplots(1, figsize=(10, 7))
sns.countplot(data=df_join_clean, x='source', palette='viridis', saturation=1)
plt.title('Distribution of Source of Tweets', fontdict={'fontsize': 16, 'fontweight':'bold'})
plt.xlabel('Sources', fontweight= 'bold') 
plt.ylabel('Frequency', fontweight= 'bold')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df_join_clean[['source']].describe().T
# Out:
#        count unique                 top  freq
# source  2006      3  Twitter for iPhone  1966

# %% [markdown]
# > iPhone users are overwhelmingly represented in this dataset, making up more than 90% of all users

# %%
# univariate plot of dog_class
fig, ax = plt.subplots(1, figsize=(10, 7))
sns.countplot(data=df_join_clean, x='dog_class', palette='viridis')
plt.title('Distribution of Dog Class', fontdict={'fontsize': 16, 'fontweight':'bold'})
plt.xlabel('Dog Classes', fontweight= 'bold') 
plt.ylabel('Frequency', fontweight= 'bold')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df_join_clean[['dog_class']].describe().T
# Out:
#           count unique           top  freq
# dog_class  2006      5  unclassified  1712

# %% [markdown]
# > Most of the dogs were not classified according to the WeRateDogs classification system

# %%
# univariate plot of dog_class without unclassified dogs
g = df_join_clean.query("dog_class != 'unclassified'")

fig, ax = plt.subplots(1, figsize=(10, 7))
sns.countplot(data=g, x='dog_class', palette='viridis')
plt.title('Distribution of Dog Class (excluding unclassified dogs)', fontdict={'fontsize': 16, 'fontweight':'bold'})
plt.xlabel('Dog Classes', fontweight= 'bold') 
plt.ylabel('Frequency', fontweight= 'bold')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# > Excluding the unclassified category, we see clearly that most dogs were rated as "puppers".<br>
# Defined according to the Dogtionary, as:<br> "A small doggo. Usually younger.... A doggo that is inexperienced, unfamiliar, or in any wa unprepared for the responsibilities associated with being a doggo"

# %%
# univariate plot of predicted_breed (top 90)
sns.set_palette('viridis')
sns.set_style('dark')
fig, ax = plt.subplots(1, figsize=(24, 7))
df_join_clean['predicted_breed'].value_counts()[:90].plot.bar(x='predicted_breed', ax=ax,)
plt.title('Distribution of The 90 Most Occuring Predicted Breed', fontdict={'fontsize': 16, 'fontweight':'bold'})
plt.xlabel('Breeds', fontweight= 'bold') 
plt.ylabel('Frequency', fontweight= 'bold')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df_join_clean[['predicted_breed']].describe().T
# Out:
#                 count unique               top freq
# predicted_breed  2006    344  Golden Retriever  158

# %% [markdown]
# > Golden and Labrador Retrievers are generously represented in this data

# %% [markdown]
# ### `Continuous Data`
# ------

# %%
# selecting continuous data
df_join_clean.select_dtypes(include=['int64', 'float64']).columns
# Out:
# Index(['img_num', 'retweet_count', 'favorite_count', 'rating_numerator',
#        'rating_denominator', 'conf'],
#       dtype='object')

# %%
# plotting histogram of num_images
sns.set_style('whitegrid')

fig, ax = plt.subplots(1, figsize=(10, 7))
plt.title('Distribution of Number of Images in a Tweet', fontdict={'fontweight':'bold', 'fontsize':13})
plt.xlabel("Number of Images", fontweight='bold')
plt.xlabel("Count", fontweight='bold')

sns.histplot(data=df_join_clean, x='img_num', palette='viridis', ax=ax)
# Out:
# <AxesSubplot:title={'center':'Distribution of Number of Images in a Tweet'}, xlabel='Count', ylabel='Count'>

# %%
# summary statistics for 'img_num'
df_join_clean[['img_num']].describe().T
# Out:
#           count      mean       std  min  25%  50%  75%  max
# img_num  2006.0  1.202891  0.559846  1.0  1.0  1.0  1.0  4.0

# %% [markdown]
# > Just a few tweets contain more than 1 pictures

# %% [markdown]
# >

# %%
# plotting histogram of retweet_count and favorite_count
sns.set_style('whitegrid')
sns.set_palette('viridis')

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20, 7))
plt.suptitle("Distributions of The Count of Times Tweet was Retweeted and 'Favorited'", fontweight='bold', fontsize=15)
sns.histplot(data=df_join_clean, x='retweet_count', ax=ax1)
sns.histplot(data=df_join_clean, x='favorite_count', ax=ax2)
# Out:
# <AxesSubplot:xlabel='favorite_count', ylabel='Count'>

# %%
# summary statistics for 'retweet_count' and 'favorite_count'
df_join_clean[['retweet_count', 'favorite_count']].describe().T
# Out:
#                  count         mean           std   min      25%     50%  \
# retweet_count   2006.0  2623.465603   4696.055329  11.0   579.25  1258.0
# favorite_count  2006.0  8643.965603  12743.343899   0.0  1808.25  3865.5
#
#                      75%       max
# retweet_count    2987.50   83310.0
# favorite_count  10782.75  163821.0

# %% [markdown]
# > The histograms show much skewness to the right indicating that most tweets were not favorited or retweeted much or at all. But very few tweets have retweets in the excess of 80,000

# %%
sns.set_style('whitegrid')
sns.set_palette('viridis')

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20, 7))
plt.suptitle("Distributions of The Rating Scores", fontweight='bold', fontsize=15)
sns.histplot(data=df_join_clean, x='rating_numerator', ax=ax1)
sns.rugplot(data=df_join_clean, x='rating_numerator', ax=ax1)

sns.histplot(data=df_join_clean, x='rating_denominator', ax=ax2)
sns.rugplot(data=df_join_clean, x='rating_denominator', ax=ax2)
# Out:
# <AxesSubplot:xlabel='rating_denominator', ylabel='Count'>

# %%
df_join_clean[['rating_numerator', 'rating_denominator']].describe().T
# Out:
#                      count       mean        std  min   25%   50%   75%  \
# rating_numerator    2006.0  12.222223  41.337923  0.0  10.0  11.0  12.0
# rating_denominator  2006.0  10.506979   7.239866  7.0  10.0  10.0  10.0
#
#                        max
# rating_numerator    1776.0
# rating_denominator   170.0

# %% [markdown]
# > As expected with any form of score data, the ratings histogram is highly right-skewed with medians of 11 & 10 for the numerator and denominator ratings respectively and maximum ratings of 1776 & 170 respectively

# %%
sns.set_style('whitegrid')
sns.set_palette('viridis')

fig, ax = plt.subplots(1, figsize=(10, 7))
plt.title('Distribution of the Neural Network Prediction Confidence Level', fontdict={'fontweight':'bold', 'fontsize':15})

sns.histplot(data=df_join_clean, x='conf', bins=30, ax=ax)
plt.xlabel('Confidence Levels', fontweight='bold')
plt.ylabel('Count', fontweight='bold')
# Out:
# Text(0, 0.5, 'Count')

# %%
df_join_clean[['conf']].describe().T
# Out:
#        count      mean       std           min       25%      50%       75%  \
# conf  2006.0  0.470728  0.329436  1.740170e-10  0.144077  0.45607  0.774378
#
#            max
# conf  0.999956

# %% [markdown]
# > The distribution of confidence levels is bimodal implying that for most of the tweets, the neural network is either very confident or very uncertain in its predictions of the contents of the pictures

# %% [markdown]
# ## ***Analyses***
# ### ***Question 1***: What dog breed was rated the highest?
# ### ***Code***
#
# I decide to use the numerator of the ratings as a a measure for ratings because even though the ratings have no standard scale, the numerator ratings are a better candidate for this measure than the denominator of the ratings

# %%
# filtering top 20 breeds most occuring breeds
a = df_join_clean['predicted_breed'].value_counts().head(20).index.to_list()
mask = df_join_clean['predicted_breed'].isin(a)

# %%
# applying mask
g = df_join_clean[mask]

# %%
# grouping by breed and getting the mean of rating_numerator
df = g.groupby('predicted_breed')['rating_numerator'].mean().sort_values(ascending=False).head(20)

# %%
# viewing the .groupby result
df.head()
# Out:
# predicted_breed
# Chow                  14.166667
# Labrador Retriever    13.625000
# Golden Retriever      13.085443
# Samoyed               11.731707
# Eskimo Dog            11.409091
# Name: rating_numerator, dtype: float64

# %% [markdown]
# ### ***Visualization***

# %%
# visualizing
sns.set_style('whitegrid')
sns.set_palette('viridis')

fig, ax = plt.subplots(1, figsize=(20, 7))
ax = df.plot.bar()

plt.title('Highest Rated Dog Breeds', fontsize=15, fontweight='bold')
plt.ylabel('Mean of Ratings(numerator)',fontweight='bold')
plt.xlabel('Predicted Breed', fontweight='bold')
# Out:
# Text(0.5, 0, 'Predicted Breed')

# %% [markdown]
# ### ***Insight***
# The highest rated dog by rating numerator is the Chow with a mean numerator rating of 14.166667

# %% [markdown]
# -----
# ### ***Question 2***: What dog class was retweeted the most?
# ### ***Code***
# ### ***Visualizations***

# %%
# visualizing distribution

sns.catplot(
x="dog_class", y="retweet_count", data=g, kind='box', palette='viridis', height=8
)
plt.title('Boxplots Showing the Distribution of Retweets Count for each Dog Class', fontweight='bold', fontsize=15)
plt.xlabel('Dog Class', fontweight='bold')
plt.ylabel('Count of Retweets', fontweight='bold')
# Out:
# Text(-6.949999999999996, 0.5, 'Count of Retweets')

# %% [markdown]
# > Looking at the boxplots alone, it seems floofers are retweeted more often than the others...

# %%
# visualizing scatterplots
fig, ax = plt.subplots( figsize=(10,7))
sns.stripplot(
x="dog_class", y="retweet_count", data=g, palette='viridis', ax=ax
)
plt.title('Stripplots of Count of Retweets for each Dog Class', fontweight='bold', fontsize=15)
plt.xlabel('Dog Class', fontweight='bold')
plt.ylabel('Count of Retweets', fontweight='bold')
# Out:
# Text(0, 0.5, 'Count of Retweets')

# %%
# grouping by dog class and taking aggregations of retweet count
df_join_clean.groupby('dog_class')['retweet_count'].agg(['mean','median', 'count'])
# Out:
#                      mean  median  count
# dog_class
# doggo         6201.484848  2811.5     66
# floofer       8002.000000  3611.0      3
# pupper        2220.793103  1073.0    203
# puppo         6899.681818  2940.5     22
# unclassified  2468.898364  1221.0   1712

# %% [markdown]
# > However, the stripplot and table show the clearer picture: the four dog classes have very different counts

# %% [markdown]
# ### ***Insights***
#
#  - The four dog classes have very different counts so its quite difficult to make a comparison across them
#  - I therefore cannot conclude conclusively that there are any differences in the retweet counts among the dog classes

# %% [markdown]
# -----
# ### ***Question 3***: What trends are there in tweet activity over time?
# ### ***Code***

# %%
# Calculating how many tweets from 2015 are in this dataframe
criteria = df_join_clean['timestamp'].dt.year == 2015
min =df_join_clean.loc[criteria, 'timestamp'].dt.dayofyear.min()
max = df_join_clean.loc[criteria, 'timestamp'].dt.dayofyear.max()
no_of_days = max - min
print(f"There were {no_of_days} days of tweet activity in 2015")
# Out:
# There were 46 days of tweet activity in 2015

# %%
# Calculating how many tweets from 2016 are in this dataframe
criteria = df_join_clean['timestamp'].dt.year == 2016
min =df_join_clean.loc[criteria, 'timestamp'].dt.dayofyear.min()
max = df_join_clean.loc[criteria, 'timestamp'].dt.dayofyear.max()
no_of_days = max - min
print(f"There were {no_of_days} days of tweet activity in 2016")
# Out:
# There were 365 days of tweet activity in 2016

# %%
# Calculating how many tweets from 2017 are in this dataframe
criteria = df_join_clean['timestamp'].dt.year == 2017
min =df_join_clean.loc[criteria, 'timestamp'].dt.dayofyear.min()
max = df_join_clean.loc[criteria, 'timestamp'].dt.dayofyear.max()
no_of_days = max - min
print(f"There were {no_of_days} days of tweet activity in 2017")
# Out:
# There were 212 days of tweet activity in 2017

# %% [markdown]
# ### ***Visualizations***

# %%
# Visualising count of tweet activity
sns.set_palette('viridis')
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday',
'Friday', 'Saturday', 'Sunday']
title = 'Counts of Tweets Per Day in The WeRateDogs Twitter Archive'
fig, ax = plt.subplots(figsize=(10, 7))
(df_join_clean
['timestamp']
.dt.day_name() 
.value_counts()
.reindex(days)
.plot.barh(ax=ax)
)
plt.title(title,fontweight='bold', fontsize=15)
plt.xlabel("Number of Tweets",fontweight='bold')
plt.ylabel("Day of the Week",fontweight='bold')
# Out:
# Text(0, 0.5, 'Day of the Week')

# %% [markdown]
# > Most WeRateDog users tweet on Mondays

# %%
# Visualising count of tweet activity per year
sns.set_palette('viridis')
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday',
'Friday', 'Saturday', 'Sunday']
title = 'Counts of Tweets Per Year in The WeRateDogs Twitter Archive'
fig, ax = plt.subplots(figsize=(10, 7))
(df_join_clean
['timestamp']
.dt.year 
.value_counts()
.plot.barh(ax=ax)
)
plt.title(title,fontweight='bold', fontsize=15)
plt.xlabel("Number of Tweets",fontweight='bold')
plt.ylabel("Day of the Week",fontweight='bold')
# Out:
# Text(0, 0.5, 'Day of the Week')

# %% [markdown]
# > Most tweets in the dataset was from 2016.

# %%
# Heatmap of tweet activity 
fig, ax = plt.subplots(figsize=(13, 8))
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday',
'Friday', 'Saturday', 'Sunday']
table = (df_join_clean
.groupby([df_join_clean['timestamp'].dt.year.rename('year'),
df_join_clean['timestamp'].dt.day_name().
rename('day')])
.size()
.unstack('day')
.reindex(columns=days)
)
sns.heatmap(table,cmap='rocket_r', ax=ax)
title='Heatmap Visualizing Tweet Activity Per Day Per Year '
plt.title(title,fontweight='bold', fontsize=15)
plt.xlabel("Day of the Week",fontweight='bold')
plt.ylabel("Year",fontweight='bold')
# Out:
# Text(97.0, 0.5, 'Year')

# %%
df_join_clean.groupby([df_join_clean['timestamp'].dt.year.rename('year'),df_join_clean['timestamp'].dt.day_name().rename('day')]).size().unstack('day').reindex(columns=days)
# Out:
# day   Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# year
# 2015     111       96         95        99      86        83      94
# 2016     163      145        148       136     137       127     121
# 2017      56       57         57        48      61        45      41

# %% [markdown]
# > In all three years, WeRateDogs users tweeted mostly on Mondays. In 2015, Saturday has the lowest tweet activity

# %%
# Heatmap of tweet activity 
fig, ax = plt.subplots(figsize=(13, 8))
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday',
'Friday', 'Saturday', 'Sunday']
table = (df_join_clean
.groupby([df_join_clean['timestamp'].dt.hour.rename('hour'),
df_join_clean['timestamp'].dt.day_name().
rename('day')])
.size()
.unstack('day')
.reindex(columns=days)
)
sns.heatmap(table,cmap='rocket_r', ax=ax)
title='Heatmap Visualizing Tweet Activity Per Hour Per Day '
plt.title(title,fontweight='bold', fontsize=15)
plt.xlabel("Day of the Week",fontweight='bold')
plt.ylabel("Hour of Day",fontweight='bold')
# Out:
# Text(97.0, 0.5, 'Hour of Day')

# %% [markdown]
# > This heatmap tells an interesting story. First, a lot of tweets are tweeted in the wee-hours of the morning, from 12 midnight till 4 a.m. From 5 a.m., onwards till 1 p.m. tweet activity declined sharply, most likely due to users being busy at work. From 3 p.m. to 5 p.m, tweet activity picks up again. For much of the evenings and night, tweet activity remains moderate, except on some days like Mondays and Sundays, where tweet activity is fairly high at 11 p.m. Sunday being the last day of the weekend so perhaps tweeters try and spend the most of their remaining weekend hours rating dogs. And perhaps the high activity on Mondat midnight can be explained by tweetrs trying to down the Monday blues.
#
# > This is all speculation of course and I do not state affirmatively that this is actually the case.

# %% [markdown]
# ### ***Insights***
#
#  -  Most WeRateDog users tweet on Mondays
#  - Most tweets in the dataset was from 2016.
#  - In all three years, WeRateDogs users tweeted mostly on Mondays. In 2015, Saturday has the lowest tweet activity
#  - Tweets activity is highest in the the wee-hours of the morning, declining by dawn and picking up again in the late afternoon and throughout the night

# %% [markdown]
# <a id='conclusion'></a>
# # `Conclusion`

# %% [markdown]
# After wrangling and merging data about WeRateDogs tweet activity from 3 sources, I posed and answered the following questions:
# > **What dog breed gets rated the highest?** -> Chow with a mean numerator rating of 14.166667<br>
# >
# > **What dog class gets retweeted the most?** ->  Inconclusive in this case, since the four dog classes have very different counts<br>
# >
# > **What trends are there in tweet activity in over time?** -> In all three years, WeRateDogs users tweeted mostly on Mondays. Also, a lot of tweets are tweeted in the early hours of the morning, declining by dawn and picking up again in the late afternoon and throughout the night
#
# I also discovered that:
#  - Golden and Labrador Retrievers are generously represented in this data
#  - Excluding the unclassified category, most dogs were rated as "puppers"
#  - iPhone users are overwhelmingly represented in this dataset, making up more than 90% of all users

# %% [markdown]
# ### Limitations
# This following should be noted while deriving insights from this analysis:
#  - Since statistical inference was not performed, these findings cannot be said to apply to the entire population of WeRateDogs users
#  - Further analysis can be done, especially time series analysis to shed more light on tweet activity

# %% [markdown]
# <a id='report'><a>
# # `Report`

# %% [markdown]
# The report can be viewed __[here](https://drive.google.com/file/d/1r_GPMLMiH_ilXPbJQn8GBASq5JjVaGBN/view?usp=sharing)__
